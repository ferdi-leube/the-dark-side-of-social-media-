# %%
# two datasets, deciding on later which to take
# want to take in for suethe suicide part of first dataset
# ask ksenia if already scaling will be a problem for when integrating in features for regressio model

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r"C:\Users\leube\Downloads\gun_ownership_and_extra.csv", sep=';')
data
# Out:
#       FIP  Year    STATE    HFR  HFR_se  universl  permit  Fem_FS_S  \
# 0       1  1980  Alabama  0.608   0.031         0       0  0.824324
# 1       1  1981  Alabama  0.597   0.047         0       0  0.692308
# 2       1  1982  Alabama  0.661   0.036         0       0  0.771739
# 3       1  1983  Alabama  0.586   0.038         0       0  0.688172
# 4       1  1984  Alabama  0.624   0.036         0       0  0.710000
# ...   ...   ...      ...    ...     ...       ...     ...       ...
# 1845   56  2012  Wyoming  0.597   0.029         0       0  0.375000
# 1846   56  2013  Wyoming  0.613   0.032         0       0  0.529412
# 1847   56  2014  Wyoming  0.608   0.044         0       0  0.583333
# 1848   56  2015  Wyoming  0.549   0.032         0       0  0.393939
# 1849   56  2016  Wyoming  0.607   0.032         0       0  0.375000
#
#       Male_FS_S  BRFSS   GALLUP       GSS       PEW   HuntLic  GunsAmmo  \
# 0      0.833795   -9.0  0.55395  0.583632 -9.000000  0.291102 -0.509164
# 1      0.831126   -9.0 -9.00000 -9.000000 -9.000000  0.294962 -0.618954
# 2      0.821429   -9.0 -9.00000  0.655196 -9.000000  0.290545 -0.526692
# 3      0.819277   -9.0  0.61144 -9.000000 -9.000000  0.284983 -0.713227
# 4      0.775956   -9.0 -9.00000  0.626933 -9.000000  0.281622 -0.733305
# ...         ...    ...      ...       ...       ...       ...       ...
# 1845   0.647482   -9.0  0.66206 -9.000000  0.622224  0.545627  2.973924
# 1846   0.714286   -9.0 -9.00000 -9.000000  0.685266  0.542697  3.066252
# 1847   0.666667   -9.0 -9.00000 -9.000000 -9.000000  0.538761  3.092854
# 1848   0.661290   -9.0 -9.00000 -9.000000  0.611531  0.544356  2.910414
# 1849   0.669643   -9.0 -9.00000 -9.000000  0.725993  0.538439  2.899840
#
#        BackChk  PewQChng   BS1   BS2   BS3
# 0    -9.000000         0   0.0   0.0   0.0
# 1    -9.000000         0   1.0   0.0   0.0
# 2    -9.000000         0   2.0   0.0   0.0
# 3    -9.000000         0   3.0   0.0   0.0
# 4    -9.000000         0   4.0   0.0   0.0
# ...        ...       ...   ...   ...   ...
# 1845  1.562481         0  12.0  12.0   8.0
# 1846  1.638737         1  12.0  12.0   9.0
# 1847  1.603822         1  12.0  12.0  10.0
# 1848  1.348323         1  12.0  12.0  11.0
# 1849  1.265807         1  12.0  12.0  12.0
#
# [1850 rows x 20 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1850 entries, 0 to 1849
# Data columns (total 20 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   FIP        1850 non-null   int64
#  1   Year       1850 non-null   int64
#  2   STATE      1850 non-null   object
#  3   HFR        1850 non-null   float64
#  4   HFR_se     1850 non-null   float64
#  5   universl   1850 non-null   int64
#  6   permit     1850 non-null   int64
#  7   Fem_FS_S   1850 non-null   float64
#  8   Male_FS_S  1850 non-null   float64
#  9   BRFSS      1850 non-null   float64
#  10  GALLUP     1850 non-null   float64
#  11  GSS        1850 non-null   float64
#  12  PEW        1850 non-null   float64
#  13  HuntLic    1850 non-null   float64
#  14  GunsAmmo   1850 non-null   float64
#  15  BackChk    1850 non-null   float64
#  16  PewQChng   1850 non-null   int64
#  17  BS1        1850 non-null   float64
#  18  BS2        1850 non-null   float64
#  19  BS3        1850 non-null   float64
# dtypes: float64(14), int64(5), object(1)
# memory usage: 289.2+ KB

# %%
data.describe()
# Out:
#                FIP         Year          HFR       HFR_se     universl  \
# count  1850.000000  1850.000000  1850.000000  1850.000000  1850.000000
# mean     29.320000  1998.000000     0.441002     0.034279     0.175135
# std      15.627847    10.679965     0.144662     0.007292     0.380185
# min       1.000000  1980.000000     0.034000     0.018000     0.000000
# 25%      17.000000  1989.000000     0.366250     0.031000     0.000000
# 50%      29.500000  1998.000000     0.462000     0.032000     0.000000
# 75%      42.000000  2007.000000     0.547000     0.038000     0.000000
# max      56.000000  2016.000000     0.800000     0.047000     1.000000
#
#             permit     Fem_FS_S    Male_FS_S        BRFSS       GALLUP  \
# count  1850.000000  1850.000000  1850.000000  1850.000000  1850.000000
# mean      0.221622    -0.051958     0.616725    -8.248315    -5.734210
# std       0.415450     1.958854     0.129041     2.550064     4.514067
# min       0.000000    -9.000000     0.144928    -9.000000    -9.000000
# 25%       0.000000     0.235294     0.560104    -9.000000    -9.000000
# 50%       0.000000     0.352941     0.631413    -9.000000    -9.000000
# 75%       0.000000     0.487420     0.705409    -9.000000     0.433781
# max       1.000000     0.923077     0.873016     0.635250     0.795623
#
#                GSS          PEW      HuntLic      GunsAmmo      BackChk  \
# count  1850.000000  1850.000000  1850.000000  1.850000e+03  1850.000000
# mean     -4.754127    -6.024545     0.371159 -6.486542e-12    -4.621622
# std       4.683266     4.388225     0.280793  9.902172e-01     4.552270
# min      -9.000000    -9.000000    -9.000000 -3.466482e+00    -9.000000
# 25%      -9.000000    -9.000000     0.246924 -6.498549e-01    -9.000000
# 50%      -9.000000    -9.000000     0.341257 -3.303508e-02    -9.000000
# 75%       0.402183     0.346282     0.462227  4.225277e-01    -0.134125
# max       0.729886     0.734846     1.138084  3.934618e+00     2.822473
#
#           PewQChng          BS1          BS2          BS3
# count  1850.000000  1850.000000  1850.000000  1850.000000
# mean      0.108108     9.756757     6.000000     2.243243
# std       0.310601     3.581862     5.061188     3.581862
# min       0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     8.730000     0.270000     0.000000
# 50%       0.000000    12.000000     6.000000     0.000000
# 75%       0.000000    12.000000    11.730000     3.270000
# max       1.000000    12.000000    12.000000    12.000000

# %%
data = data[['Year','Fem_FS_S','Male_FS_S','GunsAmmo','BackChk']]

# %%
data
# Out:
#       Year  Fem_FS_S  Male_FS_S  GunsAmmo   BackChk
# 0     1980  0.824324   0.833795 -0.509164 -9.000000
# 1     1981  0.692308   0.831126 -0.618954 -9.000000
# 2     1982  0.771739   0.821429 -0.526692 -9.000000
# 3     1983  0.688172   0.819277 -0.713227 -9.000000
# 4     1984  0.710000   0.775956 -0.733305 -9.000000
# ...    ...       ...        ...       ...       ...
# 1845  2012  0.375000   0.647482  2.973924  1.562481
# 1846  2013  0.529412   0.714286  3.066252  1.638737
# 1847  2014  0.583333   0.666667  3.092854  1.603822
# 1848  2015  0.393939   0.661290  2.910414  1.348323
# 1849  2016  0.375000   0.669643  2.899840  1.265807
#
# [1850 rows x 5 columns]

# %%
def displots(data):
    import seaborn as sns
    import matplotlib.pyplot as plt
    numcol = list(data.describe().columns)
    for x in numcol:
        sns.displot(data, x=x)

# %%
def boxplots(data):
    import seaborn as sns
    import matplotlib.pyplot as plt
    numcol = list(data.describe().columns)
    for x in numcol:
        sns.boxplot(data = data, y=x)
        plt.title(x)
        plt.show()

# %%
displots(data)

# %%
boxplots(data)

# %%
# a few outliers esecially for female suicide a very weird low value, theoretically though possible having very diffferent
# values for the different states, to different wepons torwards wepons, laws etc, also in this case I do not need to do a model
# etc. where these outliers could mess up my training set

# when grouping by year I might just take median instead of mean so the results are not affecte as much from outliers

# %%
pivot = pd.pivot_table(data=data,index='Year',values=['Fem_FS_S','Male_FS_S','GunsAmmo','BackChk'], aggfunc='median')

# %%
pivot.reset_index(inplace=True)

# %%
# lets get rid of preictions we dont need, year wise
finito = pivot[pivot['Year']>=2008]

# %%
for x in list(finito.describe().columns)[1:]:
    sns.lineplot(data=finito,x='Year',y=x)
    plt.legend()
    plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# male suicide level no real increase over time, gun ownership and female suicide strong increase, as well as background checks
#

# %%
# second gun ownership dataset, total amount of firearms processed by the ATF
data2 = pd.read_csv(r"C:\Users\leube\Downloads\National_Firearms_Act_Firearms_Processed_by_Form_Type.csv")
data2
# Out:
#     Calendar_Year ATF_Form_1 ATF_Form_2 ATF_Form_3 ATF_Form_4 ATF_Form_5  \
# 0            1990        399     66,084     23,149      7,024     54,959
# 1            1991        524     80,619     19,507      5,395     44,146
# 2            1992        351    107,313     26,352      6,541     45,390
# 3            1993        310     70,342     22,071      7,388     60,193
# 4            1994      1,076     97,665     27,950      7,600     67,580
# 5            1995      1,226     95,061     18,593      8,263     60,055
# 6            1996      1,174    103,511     16,931      6,418     72,395
# 7            1997        855    110,423     18,371      7,873     70,690
# 8            1998      1,093    141,101     27,921     10,181     93,135
# 9            1999      1,071    137,373     28,288     11,768     95,554
# 10           2000      1,334    141,763     23,335     11,246     96,234
# 11           2001      2,522    145,112     25,745     10,799    101,955
# 12           2002      1,173    162,321     25,042     10,686     92,986
# 13           2003      1,003    156,620     21,936     13,501    107,108
# 14           2004        980     83,483     20,026     14,635     54,675
# 15           2005      1,902     65,865     26,603     14,606     26,210
# 16           2006      2,610    188,134     51,290     20,534    100,458
# 17           2007      3,553    296,267     51,217     22,260    194,794
# 18           2008      4,583    424,743     71,404     26,917    183,271
# 19           2009      5,345    371,920     56,947     31,551    201,267
# 20           2010      5,169    296,375     58,875     33,059    189,449
# 21           2011      5,477    530,953    107,066     33,816    147,341
# 22           2012      7,886    484,928    149,762     52,490    170,561
# 23           2013      9,347    477,567    206,389     57,294    110,637
# 24           2014     22,380    591,388    262,342    107,921    138,204
#
#    ATF_Form_9      Total
# 0      21,725    173,340
# 1      40,387    190,578
# 2      22,120    208,067
# 3      24,041    184,345
# 4      34,242    236,113
# 5      31,258    214,456
# 6      40,439    240,868
# 7      36,284    244,496
# 8      40,221    313,652
# 9      28,128    302,182
# 10     28,672    302,584
# 11     25,759    311,892
# 12     47,597    339,805
# 13     43,668    343,836
# 14     19,425    193,224
# 15     20,951    156,137
# 16     42,175    405,201
# 17     76,467    644,558
# 18    206,411    917,329
# 19    163,951    830,981
# 20    136,335    719,262
# 21    311,214  1,135,867
# 22    219,700  1,085,327
# 23    224,515  1,085,749
# 24    248,109  1,370,344

# %%
# all we need is year and total number of registered and processed weapons
dataweap = data2[['Calendar_Year','ATF_Form_2']]
dataweap
# Out:
#     Calendar_Year ATF_Form_2
# 0            1990     66,084
# 1            1991     80,619
# 2            1992    107,313
# 3            1993     70,342
# 4            1994     97,665
# 5            1995     95,061
# 6            1996    103,511
# 7            1997    110,423
# 8            1998    141,101
# 9            1999    137,373
# 10           2000    141,763
# 11           2001    145,112
# 12           2002    162,321
# 13           2003    156,620
# 14           2004     83,483
# 15           2005     65,865
# 16           2006    188,134
# 17           2007    296,267
# 18           2008    424,743
# 19           2009    371,920
# 20           2010    296,375
# 21           2011    530,953
# 22           2012    484,928
# 23           2013    477,567
# 24           2014    591,388

# %%
dataweap.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Calendar_Year  25 non-null     int64
#  1   ATF_Form_2     25 non-null     object
# dtypes: int64(1), object(1)
# memory usage: 528.0+ bytes

# %%
dataweap['ATF_Form_2'] = dataweap['ATF_Form_2'].apply(pd.to_numeric)

# wrongnumber format in string here
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda4\lib\site-packages\pandas\_libs\lib.pyx:2315, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "66,084"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Input In [137], in <cell line: 1>()
# ----> 1 dataweap['ATF_Form_2'] = dataweap['ATF_Form_2'].apply(pd.to_numeric)
#
# File ~\anaconda4\lib\site-packages\pandas\core\series.py:4433, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4323 def apply(
#    4324     self,
#    4325     func: AggFuncType,
#    (...)
#    4328     **kwargs,
#    4329 ) -> DataFrame | Series:
#    4330     """
#    4331     Invoke function on values of Series.
#    4332
#    (...)
#    4431     dtype: float64
#    4432     """
# -> 4433     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~\anaconda4\lib\site-packages\pandas\core\apply.py:1082, in SeriesApply.apply(self)
#    1078 if isinstance(self.f, str):
#    1079     # if we are a string, try to dispatch
#    1080     return self.apply_str()
# -> 1082 return self.apply_standard()
#
# File ~\anaconda4\lib\site-packages\pandas\core\apply.py:1137, in SeriesApply.apply_standard(self)
#    1131         values = obj.astype(object)._values
#    1132         # error: Argument 2 to "map_infer" has incompatible type
#    1133         # "Union[Callable[..., Any], str, List[Union[Callable[..., Any], str]],
#    1134         # Dict[Hashable, Union[Union[Callable[..., Any], str],
#    1135         # List[Union[Callable[..., Any], str]]]]]"; expected
#    1136         # "Callable[[Any], Any]"
# -> 1137         mapped = lib.map_infer(
#    1138             values,
#    1139             f,  # type: ignore[arg-type]
#    1140             convert=self.convert_dtype,
#    1141         )
#    1143 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1144     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1145     #  See also GH#25959 regarding EA support
#    1146     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~\anaconda4\lib\site-packages\pandas\_libs\lib.pyx:2870, in pandas._libs.lib.map_infer()
#
# File ~\anaconda4\lib\site-packages\pandas\core\tools\numeric.py:184, in to_numeric(arg, errors, downcast)
#     182 coerce_numeric = errors not in ("ignore", "raise")
#     183 try:
# --> 184     values, _ = lib.maybe_convert_numeric(
#     185         values, set(), coerce_numeric=coerce_numeric
#     186     )
#     187 except (ValueError, TypeError):
#     188     if errors == "raise":
#
# File ~\anaconda4\lib\site-packages\pandas\_libs\lib.pyx:2357, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "66,084" at position 0

# %%
newval = []
for x in list(dataweap['ATF_Form_2'].values):
    new = x.replace(',','')
    newval.append(new)

# %%
newval
# Out:
# ['66084',
#  '80619',
#  '107313',
#  '70342',
#  '97665',
#  '95061',
#  '103511',
#  '110423',
#  '141101',
#  '137373',
#  '141763',
#  '145112',
#  '162321',
#  '156620',
#  '83483',
#  '65865',
#  '188134',
#  '296267',
#  '424743',
#  '371920',
#  '296375',
#  '530953',
#  '484928',
#  '477567',
#  '591388']

# %%
dataweap['ATF_Form_2'] = newval
del dataweap['Total']
# Out:
# C:\Users\leube\AppData\Local\Temp\ipykernel_6440\2193413800.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataweap['ATF_Form_2'] = newval

# %%
dataweap['ATF_Form_2'] = dataweap['ATF_Form_2'].apply(pd.to_numeric)
# Out:
# C:\Users\leube\AppData\Local\Temp\ipykernel_6440\3064245724.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataweap['ATF_Form_2'] = dataweap['ATF_Form_2'].apply(pd.to_numeric)

# %%
dataweap = dataweap[dataweap['Calendar_Year']>=2002]

# %%
sns.lineplot(data=dataweap,x='Calendar_Year',y='ATF_Form_2')
# Out:
# <AxesSubplot:xlabel='Calendar_Year', ylabel='ATF_Form_2'>

# %%
# strong increase of total registered weapons by the ATF

# %%
# lets make forcast until year 2018

from statsmodels.tsa.seasonal import seasonal_decompose
decompose = seasonal_decompose(dataweap['ATF_Form_2'],model='additive', period=2)
decompose.plot()
plt.show()

# %%
from statsmodels.tsa.stattools import acf, pacf
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
plot_acf(dataweap['ATF_Form_2'], lags=6)

# %%
# no auto correlation

# stationary?
from statsmodels.tsa.stattools import adfuller
adft = adfuller(dataweap['ATF_Form_2'],autolag="AIC")
output_df = pd.DataFrame({"Values":[adft[0],adft[1],adft[2],adft[3], adft[4]['1%'], adft[4]['5%'], adft[4]['10%']]  , "Metric":["Test Statistics","p-value","No. of lags used","Number of observations used",
                                                        "critical value (1%)", "critical value (5%)", "critical value (10%)"]})
print(output_df)
# Out:
#      Values                       Metric
# 0 -1.086144              Test Statistics
# 1  0.720566                      p-value
# 2  4.000000             No. of lags used
# 3  8.000000  Number of observations used
# 4 -4.665186          critical value (1%)
# 5 -3.367187          critical value (5%)
# 6 -2.802961         critical value (10%)

# %%
# data not stationary due to high p value, so lets either make ot stationary first or use arima doing this step for us

# %%
len(dataweap)
# Out:
# 13

# %%
train = dataweap['ATF_Form_2'][:11]
test = dataweap['ATF_Form_2'][11:]

# %%
from pmdarima.arima import auto_arima
model = auto_arima(train, trace=True, error_action='ignore', suppress_warnings=True, seasonal=False,  m=12)
model.fit(train)
# Out:
# C:\Users\leube\AppData\Roaming\Python\Python39\site-packages\pmdarima\arima\_validation.py:62: UserWarning: m (12) set for non-seasonal fit. Setting to 0
#   warnings.warn("m (%i) set for non-seasonal fit. Setting to 0" % m)
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=0.13 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=311.919, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=292.141, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=309.575, Time=0.02 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=294.167, Time=0.05 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=294.300, Time=0.04 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=295.546, Time=0.05 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=291.560, Time=0.02 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=297.829, Time=0.02 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=293.377, Time=0.03 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=292.983, Time=0.13 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=292.848, Time=0.03 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.10 sec
#
# Best model:  ARIMA(1,0,0)(0,0,0)[0] intercept
# Total fit time: 0.666 seconds
# ARIMA(order=(1, 0, 0), scoring_args={}, suppress_warnings=True)

# %%
test
# Out:
# 23    477567
# 24    591388
# Name: ATF_Form_2, dtype: int64

# %%
predtest = model.predict(n_periods=len(test))
predtest = pd.DataFrame(predtest,index = test.index,columns=['Prediction'])

# %%
test
# Out:
# 23    477567
# 24    591388
# Name: ATF_Form_2, dtype: int64

# %%
from sklearn.metrics import r2_score
r2_score(predtest,test)

# very bad results due to small amount of data, better resuls with linear regression??

# first lets try building timeseries with all the data from previous years
# Out:
# -58.841402849827126

# %%
dataweapall = data2[['Calendar_Year','ATF_Form_2']]

# %%
dataweapall
# Out:
#     Calendar_Year ATF_Form_2
# 0            1990     66,084
# 1            1991     80,619
# 2            1992    107,313
# 3            1993     70,342
# 4            1994     97,665
# 5            1995     95,061
# 6            1996    103,511
# 7            1997    110,423
# 8            1998    141,101
# 9            1999    137,373
# 10           2000    141,763
# 11           2001    145,112
# 12           2002    162,321
# 13           2003    156,620
# 14           2004     83,483
# 15           2005     65,865
# 16           2006    188,134
# 17           2007    296,267
# 18           2008    424,743
# 19           2009    371,920
# 20           2010    296,375
# 21           2011    530,953
# 22           2012    484,928
# 23           2013    477,567
# 24           2014    591,388

# %%
newval = []
for x in list(dataweapall['Total'].values):
    new = x.replace(',','')
    newval.append(new)
dataweapall['Total'] = newval
dataweapall['Total'] = dataweapall['Total'].apply(pd.to_numeric)
# Out:
# C:\Users\leube\AppData\Local\Temp\ipykernel_6440\1655888403.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataweapall['Total'] = newval
# C:\Users\leube\AppData\Local\Temp\ipykernel_6440\1655888403.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataweapall['Total'] = dataweapall['Total'].apply(pd.to_numeric)

# %%
#autocorrelation?

plot_acf(dataweapall['Total'], lags=6)

# %% [markdown]
# utocorrelation with first 2 lags

# %%
# stationary ?
adft = adfuller(dataweapall['Total'],autolag="AIC")
output_df = pd.DataFrame({"Values":[adft[0],adft[1],adft[2],adft[3], adft[4]['1%'], adft[4]['5%'], adft[4]['10%']]  , "Metric":["Test Statistics","p-value","No. of lags used","Number of observations used",
                                                        "critical value (1%)", "critical value (5%)", "critical value (10%)"]})
print(output_df)
# Out:
#       Values                       Metric
# 0   2.633284              Test Statistics
# 1   0.999081                      p-value
# 2   8.000000             No. of lags used
# 3  16.000000  Number of observations used
# 4  -3.924019          critical value (1%)
# 5  -3.068498          critical value (5%)
# 6  -2.673893         critical value (10%)

# %% [markdown]
# not stationary, H0 excepted due to high p value

# %%
# decomposition

decompose = seasonal_decompose(dataweapall['Total'],model='additive', period=2)
decompose.plot()
plt.show()

# %%
split = round((len(dataweapall)*0.8))

train = dataweapall['Total'][:split]
test = dataweapall['Total'][split:]

# %%
from pmdarima.arima import auto_arima
model2 = auto_arima(train, trace=True, error_action='ignore', suppress_warnings=True, seasonal=False,  m=12)
model2.fit(train)
# Out:
# C:\Users\leube\AppData\Roaming\Python\Python39\site-packages\pmdarima\arima\_validation.py:62: UserWarning: m (12) set for non-seasonal fit. Setting to 0
#   warnings.warn("m (%i) set for non-seasonal fit. Setting to 0" % m)
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=217.011, Time=0.06 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=215.834, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=199.099, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=215.954, Time=0.02 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=inf, Time=0.05 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=inf, Time=0.17 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=196.066, Time=0.01 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=194.787, Time=0.01 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.06 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=217.839, Time=0.07 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 0.488 seconds
# ARIMA(order=(0, 0, 0), scoring_args={}, suppress_warnings=True)

# %%
test
# Out:
# 20     719262
# 21    1135867
# 22    1085327
# 23    1085749
# 24    1370344
# Name: Total, dtype: int64

# %%
predtest = model2.predict(n_periods=len(test))
predtest = pd.DataFrame(predtest,index = test.index,columns=['Prediction'])

r2_score(predtest,test)

# very bad results due to small amount of data, better resuls with linear regression??

# first lets try building timeseries with all the data from previous years
# Out:
# -3.4648989716298914e+30

# %%
predtest['Prediction']
# Out:
# 20    1.020694e+06
# 21    1.020694e+06
# 22    1.020694e+06
# 23    1.020694e+06
# 24    1.020694e+06
# Name: Prediction, dtype: float64

# %%
#linear regression
dataweap
# Out:
#     Calendar_Year  ATF_Form_2
# 12           2002      162321
# 13           2003      156620
# 14           2004       83483
# 15           2005       65865
# 16           2006      188134
# 17           2007      296267
# 18           2008      424743
# 19           2009      371920
# 20           2010      296375
# 21           2011      530953
# 22           2012      484928
# 23           2013      477567
# 24           2014      591388

# %%
sns.lineplot(data=dataweap,x='Calendar_Year',y='ATF_Form_2')
# Out:
# <AxesSubplot:xlabel='Calendar_Year', ylabel='ATF_Form_2'>

# %%
import statsmodels.api as sm

X = sm.add_constant(dataweap['Calendar_Year'])
Y = dataweap['ATF_Form_2']
model = sm.OLS(Y,X)
results = model.fit()
predictions = results.predict(X)

# %%
predframe = pd.DataFrame({'Year':dataweap['Calendar_Year'],'ATF_Form_2':predictions})

# %%
sns.lineplot(data=predframe,x='Year',y='ATF_Form_2')
# Out:
# <AxesSubplot:xlabel='Year', ylabel='ATF_Form_2'>

# %%
# does in deed show the general trend, therefor better suited to predict future vaues than first attempt of using timeseries

# %%
listyear = [2015,2016,2017,2018]
newyear = pd.DataFrame({'Calendar_Year':listyear})
newX = sm.add_constant(newyear['Calendar_Year'])
newyear['ATF_Form_2'] = results.predict(newX)
allyear = pd.concat([dataweap,newyear],axis=0,ignore_index=True)

# %%
allyear
# Out:
#     Calendar_Year     ATF_Form_2
# 0            2002  162321.000000
# 1            2003  156620.000000
# 2            2004   83483.000000
# 3            2005   65865.000000
# 4            2006  188134.000000
# 5            2007  296267.000000
# 6            2008  424743.000000
# 7            2009  371920.000000
# 8            2010  296375.000000
# 9            2011  530953.000000
# 10           2012  484928.000000
# 11           2013  477567.000000
# 12           2014  591388.000000
# 13           2015  605132.461538
# 14           2016  646189.142857
# 15           2017  687245.824176
# 16           2018  728302.505495

# %%
sns.lineplot(data=allyear,x='Calendar_Year',y='ATF_Form_2')
# Out:
# <AxesSubplot:xlabel='Calendar_Year', ylabel='ATF_Form_2'>

# %%
# try it with all data
Xa = sm.add_constant(dataweapall['Calendar_Year'])
Ya = dataweapall['ATF_Form_2']
model = sm.OLS(Ya,Xa)
resultsa = model.fit()
predictionsa = results.predict(Xa)
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "C:\Users\leube\anaconda4\lib\site-packages\IPython\core\interactiveshell.py", line 3369, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\leube\AppData\Local\Temp\ipykernel_6440\3158726766.py", line 4, in <cell line: 4>
#     model = sm.OLS(Ya,Xa)
#   File "C:\Users\leube\anaconda4\lib\site-packages\statsmodels\regression\linear_model.py", line 890, in __init__
#     Returns
#   File "C:\Users\leube\anaconda4\lib\site-packages\statsmodels\regression\linear_model.py", line 717, in __init__
#     ----------
#   File "C:\Users\leube\anaconda4\lib\site-packages\statsmodels\regression\linear_model.py", line 191, in __init__
#     self._data_attr.extend(['pinv_wexog', 'weights'])
#   File "C:\Users\leube\anaconda4\lib\site-packages\statsmodels\base\model.py", line 267, in __init__
#   File "C:\Users\leube\anaconda4\lib\site-packages\statsmodels\base\model.py", line 92, in __init__
#     def _get_init_kwds(self):
#   File "C:\Users\leube\anaconda4\lib\site-packages\statsmodels\base\model.py", line 132, in _handle_data
#     *args
#   File "C:\Users\leube\anaconda4\lib\site-packages\statsmodels\base\data.py", line 673, in handle_data
#     **kwargs)
#   File "C:\Users\leube\anaconda4\lib\site-packages\statsmodels\base\data.py", line 82, in __init__
#     self.orig_exog = exog
#   File "C:\Users\leube\anaconda4\lib\site-packages\statsmodels\base\data.py", line 507, in _convert_endog_exog
#     if endog.dtype == object or exog is not None and exog.dtype == object:
# ValueError: Pandas data cast to numpy dtype of object. Check input data with np.asarray(data).
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\leube\anaconda4\lib\site-packages\IPython\core\interactiveshell.py", line 1982, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#   File "C:\Users\leube\anaconda4\lib\site-packages\IPython\core\ultratb.py", line 1118, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "C:\Users\leube\anaconda4\lib\site-packages\IPython\core\ultratb.py", line 1012, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "C:\Users\leube\anaconda4\lib\site-packages\IPython\core\ultratb.py", line 865, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "C:\Users\leube\anaconda4\lib\site-packages\IPython\core\ultratb.py", line 818, in format_exception_as_a_whole
#     frames.append(self.format_record(r))
#   File "C:\Users\leube\anaconda4\lib\site-packages\IPython\core\ultratb.py", line 736, in format_record
#     result += ''.join(_format_traceback_lines(frame_info.lines, Colors, self.has_colors, lvals))
#   File "C:\Users\leube\anaconda4\lib\site-packages\stack_data\utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "C:\Users\leube\anaconda4\lib\site-packages\stack_data\core.py", line 698, in lines
#     pieces = self.included_pieces
#   File "C:\Users\leube\anaconda4\lib\site-packages\stack_data\utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "C:\Users\leube\anaconda4\lib\site-packages\stack_data\core.py", line 649, in included_pieces
#     pos = scope_pieces.index(self.executing_piece)
#   File "C:\Users\leube\anaconda4\lib\site-packages\stack_data\utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "C:\Users\leube\anaconda4\lib\site-packages\stack_data\core.py", line 628, in executing_piece
#     return only(
#   File "C:\Users\leube\anaconda4\lib\site-packages\executing\executing.py", line 164, in only
#     raise NotOneValueFound('Expected one value, found 0')
# executing.executing.NotOneValueFound: Expected one value, found 0

# %%
listyear = [2015,2016,2017,2018]
newyear = pd.DataFrame({'Calendar_Year':listyear})
newX = sm.add_constant(newyear['Calendar_Year'])
newyear['ATF_Form_2'] = resultsa.predict(newX)
allyeara = pd.concat([dataweapall,newyear],axis=0, ignore_index=True)

# %%
allyear
# Out:
#     Calendar_Year     ATF_Form_2
# 0            2002  162321.000000
# 1            2003  156620.000000
# 2            2004   83483.000000
# 3            2005   65865.000000
# 4            2006  188134.000000
# 5            2007  296267.000000
# 6            2008  424743.000000
# 7            2009  371920.000000
# 8            2010  296375.000000
# 9            2011  530953.000000
# 10           2012  484928.000000
# 11           2013  477567.000000
# 12           2014  591388.000000
# 13           2015  605132.461538
# 14           2016  646189.142857
# 15           2017  687245.824176
# 16           2018  728302.505495

# %%
newval = []
for x in list(allyeara['ATF_Form_2'].values):
    x = str(x)
    new = x.replace(',','')
    newval.append(new)
allyeara['ATF_Form_2'] = newval
allyeara['ATF_Form_2'] = allyeara['ATF_Form_2'].apply(pd.to_numeric)

# %%
allyeara.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Calendar_Year  29 non-null     int64
#  1   ATF_Form_2     29 non-null     float64
# dtypes: float64(1), int64(1)
# memory usage: 592.0 bytes

# %%
allyeara
# Out:
#     Calendar_Year    ATF_Form_2
# 0            1990  6.608400e+04
# 1            1991  8.061900e+04
# 2            1992  1.073130e+05
# 3            1993  7.034200e+04
# 4            1994  9.766500e+04
# 5            1995  9.506100e+04
# 6            1996  1.035110e+05
# 7            1997  1.104230e+05
# 8            1998  1.411010e+05
# 9            1999  1.373730e+05
# 10           2000  1.417630e+05
# 11           2001  1.451120e+05
# 12           2002  1.623210e+05
# 13           2003  1.566200e+05
# 14           2004  8.348300e+04
# 15           2005  6.586500e+04
# 16           2006  1.881340e+05
# 17           2007  2.962670e+05
# 18           2008  4.247430e+05
# 19           2009  3.719200e+05
# 20           2010  2.963750e+05
# 21           2011  5.309530e+05
# 22           2012  4.849280e+05
# 23           2013  4.775670e+05
# 24           2014  5.913880e+05
# 25           2015  1.041292e+06
# 26           2016  1.084006e+06
# 27           2017  1.126721e+06
# 28           2018  1.169435e+06

# %%
allyeara.set_index('Calendar_Year',inplace=True)

# %%
allyeara.reset_index(inplace=True)

# %%
allyeara
# Out:
#     Calendar_Year    ATF_Form_2
# 0            1990  6.608400e+04
# 1            1991  8.061900e+04
# 2            1992  1.073130e+05
# 3            1993  7.034200e+04
# 4            1994  9.766500e+04
# 5            1995  9.506100e+04
# 6            1996  1.035110e+05
# 7            1997  1.104230e+05
# 8            1998  1.411010e+05
# 9            1999  1.373730e+05
# 10           2000  1.417630e+05
# 11           2001  1.451120e+05
# 12           2002  1.623210e+05
# 13           2003  1.566200e+05
# 14           2004  8.348300e+04
# 15           2005  6.586500e+04
# 16           2006  1.881340e+05
# 17           2007  2.962670e+05
# 18           2008  4.247430e+05
# 19           2009  3.719200e+05
# 20           2010  2.963750e+05
# 21           2011  5.309530e+05
# 22           2012  4.849280e+05
# 23           2013  4.775670e+05
# 24           2014  5.913880e+05
# 25           2015  1.041292e+06
# 26           2016  1.084006e+06
# 27           2017  1.126721e+06
# 28           2018  1.169435e+06

# %%
sns.lineplot(data=allyeara,x='Calendar_Year',y='ATF_Form_2')
# Out:
# <AxesSubplot:xlabel='Calendar_Year', ylabel='ATF_Form_2'>

# %%
# taken into account more values, lets take the allyeara dataset

# %%
# lets rather make a time series prediction, now having updated using the right columns, we see an rather exponential development
# lets make a timeseries

# %%
dataweapall
# Out:
#     Calendar_Year  ATF_Form_2
# 0            1990       66084
# 1            1991       80619
# 2            1992      107313
# 3            1993       70342
# 4            1994       97665
# 5            1995       95061
# 6            1996      103511
# 7            1997      110423
# 8            1998      141101
# 9            1999      137373
# 10           2000      141763
# 11           2001      145112
# 12           2002      162321
# 13           2003      156620
# 14           2004       83483
# 15           2005       65865
# 16           2006      188134
# 17           2007      296267
# 18           2008      424743
# 19           2009      371920
# 20           2010      296375
# 21           2011      530953
# 22           2012      484928
# 23           2013      477567
# 24           2014      591388

# %%
from autots import AutoTS, load_daily
model = AutoTS(
    forecast_length=5,
    frequency='infer',
    prediction_interval=0.4,
    ensemble=None,
    model_list="fast",  # "superfast", "default", "fast_parallel"
    transformer_list="fast",  # "superfast",
    drop_most_recent=1,
    max_generations=3,
    num_validations=3,
    validation_method="backwards",
    #min_allowed_train_percent=0.6
)

# %%
model = model.fit(
    dataweapall,
    date_col='Calendar_Year',
    value_col='ATF_Form_2'
    #id_col='series_id' if long else None,
)
# Out:
# Inferred frequency is: N
# Model Number: 1 with model AverageValueNaive in generation 0 of 3
# Model Number: 2 with model AverageValueNaive in generation 0 of 3
# Model Number: 3 with model AverageValueNaive in generation 0 of 3
# Model Number: 4 with model DatepartRegression in generation 0 of 3
# Model Number: 5 with model DatepartRegression in generation 0 of 3
# Model Number: 6 with model DatepartRegression in generation 0 of 3
# Model Number: 7 with model DatepartRegression in generation 0 of 3
# C:\Users\leube\anaconda4\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Epoch 1/50
# 1/1 [==============================] - 7s 7s/step - loss: 0.3440
# Epoch 2/50
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3449
# Epoch 3/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.3452
# Epoch 4/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.3421
# Epoch 5/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.3407
# Epoch 6/50
# 1/1 [==============================] - 0s 10ms/step - loss: 0.3419
# Epoch 7/50
# 1/1 [==============================] - 0s 18ms/step - loss: 0.3501
# Epoch 8/50
# 1/1 [==============================] - 0s 16ms/step - loss: 0.3458
# Epoch 9/50
# 1/1 [==============================] - 0s 19ms/step - loss: 0.3438
# Epoch 10/50
# 1/1 [==============================] - 0s 16ms/step - loss: 0.3463
# Epoch 11/50
# 1/1 [==============================] - 0s 17ms/step - loss: 0.3440
# Epoch 12/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.3430
# Epoch 13/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.3456
# Epoch 14/50
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3463
# Epoch 15/50
# 1/1 [==============================] - 0s 11ms/step - loss: 0.3467
# Epoch 16/50
# 1/1 [==============================] - 0s 17ms/step - loss: 0.3464
# Epoch 17/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.3437
# Epoch 18/50
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3422
# Epoch 19/50
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3462
# Epoch 20/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.3418
# Epoch 21/50
# 1/1 [==============================] - 0s 17ms/step - loss: 0.3465
# Epoch 22/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.3390
# Epoch 23/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.3436
# Epoch 24/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.3462
# Epoch 25/50
# 1/1 [==============================] - 0s 12ms/step - loss: 0.3430
# Epoch 26/50
# 1/1 [==============================] - 0s 10ms/step - loss: 0.3446
# Epoch 27/50
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3432
# Epoch 28/50
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3453
# Epoch 29/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.3497
# Epoch 30/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.3443
# Epoch 31/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.3431
# Epoch 32/50
# 1/1 [==============================] - 0s 17ms/step - loss: 0.3409
# Epoch 33/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.3462
# Epoch 34/50
# 1/1 [==============================] - 0s 16ms/step - loss: 0.3429
# Epoch 35/50
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3463
# Epoch 36/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.3437
# Epoch 37/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.3413
# Epoch 38/50
# 1/1 [==============================] - 0s 10ms/step - loss: 0.3487
# Epoch 39/50
# 1/1 [==============================] - 0s 17ms/step - loss: 0.3444
# Epoch 40/50
# 1/1 [==============================] - 0s 18ms/step - loss: 0.3488
# Epoch 41/50
# 1/1 [==============================] - 0s 10ms/step - loss: 0.3465
# Epoch 42/50
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3437
# Epoch 43/50
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3437
# Epoch 44/50
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3419
# Epoch 45/50
# 1/1 [==============================] - 0s 10ms/step - loss: 0.3392
# Epoch 46/50
# 1/1 [==============================] - 0s 10ms/step - loss: 0.3472
# Epoch 47/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.3460
# Epoch 48/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.3427
# Epoch 49/50
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3433
# Epoch 50/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.3445
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000025EDDDDF430> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 1s 1s/step
# Model Number: 8 with model ETS in generation 0 of 3
# Model Number: 9 with model ETS in generation 0 of 3
# Model Number: 10 with model GLM in generation 0 of 3
# Template Eval Error: TypeError("ufunc 'isfinite' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''") in model 10: GLM
# Model Number: 11 with model GLM in generation 0 of 3
# Model Number: 12 with model GLS in generation 0 of 3
# Model Number: 13 with model GLS in generation 0 of 3
# Model Number: 14 with model LastValueNaive in generation 0 of 3
# Model Number: 15 with model LastValueNaive in generation 0 of 3
# Model Number: 16 with model LastValueNaive in generation 0 of 3
# Model Number: 17 with model LastValueNaive in generation 0 of 3
# Model Number: 18 with model SeasonalNaive in generation 0 of 3
# Model Number: 19 with model SeasonalNaive in generation 0 of 3
# Model Number: 20 with model SeasonalNaive in generation 0 of 3
# Model Number: 21 with model VAR in generation 0 of 3
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 21: VAR
# Model Number: 22 with model VAR in generation 0 of 3
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 22: VAR
# Model Number: 23 with model VECM in generation 0 of 3
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 23: VECM
# Model Number: 24 with model VECM in generation 0 of 3
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 24: VECM
# Model Number: 25 with model WindowRegression in generation 0 of 3
# Model Number: 26 with model ConstantNaive in generation 0 of 3
# Model Number: 27 with model DatepartRegression in generation 0 of 3
# Template Eval Error: ValueError("regression_type='User' but no future_regressor passed") in model 27: DatepartRegression
# Model Number: 28 with model SeasonalNaive in generation 0 of 3
# Model Number: 29 with model DatepartRegression in generation 0 of 3
# Model Number: 30 with model ETS in generation 0 of 3
# ETS error ValueError('Cannot compute initial seasonals using heuristic method with less than two full seasonal cycles in the data.')
# ETS failed on ATF_Form_2 with ValueError('Cannot compute initial seasonals using heuristic method with less than two full seasonal cycles in the data.')
# Model Number: 31 with model VECM in generation 0 of 3
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 31: VECM
# Model Number: 32 with model MultivariateMotif in generation 0 of 3
# Template Eval Error: ValueError('The number of observations (6) is too small; the covariance matrix is singular. For observations with 10 dimensions, at least 11 observations are required.') in model 32: MultivariateMotif
# Model Number: 33 with model MultivariateMotif in generation 0 of 3
# Template Eval Error: ValueError('kth(=10) out of bounds (5)') in model 33: MultivariateMotif
# Model Number: 34 with model UnivariateMotif in generation 0 of 3
# Template Eval Error: ValueError('window shape cannot be larger than input array shape') in model 34: UnivariateMotif
# Model Number: 35 with model UnivariateMotif in generation 0 of 3
# Template Eval Error: ValueError('kth(=5) out of bounds (1)') in model 35: UnivariateMotif
# Model Number: 36 with model SectionalMotif in generation 0 of 3
# Template Eval Error: ValueError('kth(=20) out of bounds (5)') in model 36: SectionalMotif
# Model Number: 37 with model SectionalMotif in generation 0 of 3
# Template Eval Error: ValueError('kth(=10) out of bounds (10)') in model 37: SectionalMotif
# Model Number: 38 with model SeasonalNaive in generation 0 of 3
# Model Number: 39 with model DatepartRegression in generation 0 of 3
# [Parallel(n_jobs=-2)]: Using backend ThreadingBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done  36 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-2)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=7)]: Using backend ThreadingBackend with 7 concurrent workers.
# [Parallel(n_jobs=7)]: Done  36 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=7)]: Done 100 out of 100 | elapsed:    0.0s finished
# Model Number: 40 with model NVAR in generation 0 of 3
# Model Number: 41 with model ConstantNaive in generation 0 of 3
# Model Number: 42 with model LastValueNaive in generation 0 of 3
# Model Number: 43 with model AverageValueNaive in generation 0 of 3
# Model Number: 44 with model GLS in generation 0 of 3
# Model Number: 45 with model SeasonalNaive in generation 0 of 3
# Model Number: 46 with model GLM in generation 0 of 3
# Template Eval Error: ValueError('regression_type=user and no future_regressor passed') in model 46: GLM
# Model Number: 47 with model ETS in generation 0 of 3
# Model Number: 48 with model VAR in generation 0 of 3
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 48: VAR
# Model Number: 49 with model VECM in generation 0 of 3
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 49: VECM
# Model Number: 50 with model WindowRegression in generation 0 of 3
# Template Eval Error: ValueError('Found array with 0 sample(s) (shape=(0, 0)) while a minimum of 1 is required by RadiusNeighborsRegressor.') in model 50: WindowRegression
# Model Number: 51 with model DatepartRegression in generation 0 of 3
# Model Number: 52 with model UnivariateMotif in generation 0 of 3
# Template Eval Error: ValueError('window shape cannot be larger than input array shape') in model 52: UnivariateMotif
# Model Number: 53 with model MultivariateMotif in generation 0 of 3
# Template Eval Error: ValueError('window shape cannot be larger than input array shape') in model 53: MultivariateMotif
# Model Number: 54 with model SectionalMotif in generation 0 of 3
# Model Number: 55 with model NVAR in generation 0 of 3
# Template Eval Error: LinAlgError('SVD did not converge') in model 55: NVAR
# Model Number: 56 with model UnivariateMotif in generation 0 of 3
# Template Eval Error: ValueError('kth(=10) out of bounds (5)') in model 56: UnivariateMotif
# Model Number: 57 with model DatepartRegression in generation 0 of 3
# Epoch 1/50
# 3/3 [==============================] - 8s 16ms/step - loss: 38554.4609
# Epoch 2/50
# 3/3 [==============================] - 0s 9ms/step - loss: 38554.3984
# Epoch 3/50
# 3/3 [==============================] - 0s 17ms/step - loss: 38554.3242
# Epoch 4/50
# 3/3 [==============================] - 0s 20ms/step - loss: 38554.1719
# Epoch 5/50
# 3/3 [==============================] - 0s 16ms/step - loss: 38553.9883
# Epoch 6/50
# 3/3 [==============================] - 0s 22ms/step - loss: 38553.5312
# Epoch 7/50
# 3/3 [==============================] - 0s 11ms/step - loss: 38553.0938
# Epoch 8/50
# 3/3 [==============================] - 0s 17ms/step - loss: 38552.7773
# Epoch 9/50
# 3/3 [==============================] - 0s 17ms/step - loss: 38552.5352
# Epoch 10/50
# 3/3 [==============================] - 0s 17ms/step - loss: 38552.2539
# Epoch 11/50
# 3/3 [==============================] - 0s 17ms/step - loss: 38551.9492
# Epoch 12/50
# 3/3 [==============================] - 0s 15ms/step - loss: 38551.7070
# Epoch 13/50
# 3/3 [==============================] - 0s 23ms/step - loss: 38551.6133
# Epoch 14/50
# 3/3 [==============================] - 0s 16ms/step - loss: 38551.4922
# Epoch 15/50
# 3/3 [==============================] - 0s 9ms/step - loss: 38551.4180
# Epoch 16/50
# 3/3 [==============================] - 0s 7ms/step - loss: 38551.3711
# Epoch 17/50
# 3/3 [==============================] - 0s 12ms/step - loss: 38551.3008
# Epoch 18/50
# 3/3 [==============================] - 0s 9ms/step - loss: 38551.2188
# Epoch 19/50
# 3/3 [==============================] - 0s 17ms/step - loss: 38551.1914
# Epoch 20/50
# 3/3 [==============================] - 0s 25ms/step - loss: 38551.0977
# Epoch 21/50
# 3/3 [==============================] - 0s 25ms/step - loss: 38551.0156
# Epoch 22/50
# 3/3 [==============================] - 0s 13ms/step - loss: 38550.9805
# Epoch 23/50
# 3/3 [==============================] - 0s 10ms/step - loss: 38550.9258
# Epoch 24/50
# 3/3 [==============================] - 0s 15ms/step - loss: 38550.9023
# Epoch 25/50
# 3/3 [==============================] - 0s 16ms/step - loss: 38550.8516
# Epoch 26/50
# 3/3 [==============================] - 0s 23ms/step - loss: 38550.8008
# Epoch 27/50
# 3/3 [==============================] - 0s 17ms/step - loss: 38550.7578
# Epoch 28/50
# 3/3 [==============================] - 0s 19ms/step - loss: 38550.6992
# Epoch 29/50
# 3/3 [==============================] - 0s 16ms/step - loss: 38550.6758
# Epoch 30/50
# 3/3 [==============================] - 0s 18ms/step - loss: 38550.6367
# Epoch 31/50
# 3/3 [==============================] - 0s 18ms/step - loss: 38550.6055
# Epoch 32/50
# 3/3 [==============================] - 0s 20ms/step - loss: 38550.5703
# Epoch 33/50
# 3/3 [==============================] - 0s 18ms/step - loss: 38550.5117
# Epoch 34/50
# 3/3 [==============================] - 0s 17ms/step - loss: 38550.4570
# Epoch 35/50
# 3/3 [==============================] - 0s 18ms/step - loss: 38550.4258
# Epoch 36/50
# 3/3 [==============================] - 0s 19ms/step - loss: 38550.3633
# Epoch 37/50
# 3/3 [==============================] - 0s 25ms/step - loss: 38550.3320
# Epoch 38/50
# 3/3 [==============================] - 0s 11ms/step - loss: 38550.3008
# Epoch 39/50
# 3/3 [==============================] - 0s 14ms/step - loss: 38550.2773
# Epoch 40/50
# 3/3 [==============================] - 0s 14ms/step - loss: 38550.2695
# Epoch 41/50
# 3/3 [==============================] - 0s 8ms/step - loss: 38550.2383
# Epoch 42/50
# 3/3 [==============================] - 0s 13ms/step - loss: 38550.2031
# Epoch 43/50
# 3/3 [==============================] - 0s 15ms/step - loss: 38550.1484
# Epoch 44/50
# 3/3 [==============================] - 0s 8ms/step - loss: 38550.1016
# Epoch 45/50
# 3/3 [==============================] - 0s 9ms/step - loss: 38550.0664
# Epoch 46/50
# 3/3 [==============================] - 0s 23ms/step - loss: 38550.0469
# Epoch 47/50
# 3/3 [==============================] - 0s 19ms/step - loss: 38549.9844
# Epoch 48/50
# 3/3 [==============================] - 0s 21ms/step - loss: 38549.9414
# Epoch 49/50
# 3/3 [==============================] - 0s 12ms/step - loss: 38549.9062
# Epoch 50/50
# 3/3 [==============================] - 0s 15ms/step - loss: 38549.8867
# 1/1 [==============================] - 2s 2s/step
# Model Number: 58 with model GLS in generation 0 of 3
# Model Number: 59 with model ConstantNaive in generation 0 of 3
# Model Number: 60 with model SectionalMotif in generation 0 of 3
# Template Eval Error: Exception('Transformer STLFilter failed on fit') in model 60: SectionalMotif
# Model Number: 61 with model DatepartRegression in generation 0 of 3
# [Parallel(n_jobs=-2)]: Using backend ThreadingBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done  36 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-2)]: Done 186 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-2)]: Done 300 out of 300 | elapsed:    0.2s finished
# [Parallel(n_jobs=7)]: Using backend ThreadingBackend with 7 concurrent workers.
# [Parallel(n_jobs=7)]: Done  36 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=7)]: Done 186 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=7)]: Done 300 out of 300 | elapsed:    0.0s finished
# Model Number: 62 with model VECM in generation 0 of 3
# Template Eval Error: ValueError("regression_type='User' but no future_regressor supplied") in model 62: VECM
# Model Number: 63 with model MultivariateMotif in generation 0 of 3
# Template Eval Error: ValueError('window shape cannot be larger than input array shape') in model 63: MultivariateMotif
# Model Number: 64 with model SectionalMotif in generation 0 of 3
# Template Eval Error: ValueError('kth(=20) out of bounds (5)') in model 64: SectionalMotif
# Model Number: 65 with model GLM in generation 0 of 3
# Template Eval Error: ValueError('regression_type=user and no future_regressor passed') in model 65: GLM
# Model Number: 66 with model SeasonalNaive in generation 0 of 3
# Model Number: 67 with model NVAR in generation 0 of 3
# Model Number: 68 with model MultivariateMotif in generation 0 of 3
# Template Eval Error: ValueError('kth(=5) out of bounds (1)') in model 68: MultivariateMotif
# Model Number: 69 with model SectionalMotif in generation 0 of 3
# Template Eval Error: Exception('Transformer Detrend failed on fit') in model 69: SectionalMotif
# Model Number: 70 with model VAR in generation 0 of 3
# Template Eval Error: IndexError('tuple index out of range') in model 70: VAR
# Model Number: 71 with model VAR in generation 0 of 3
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 71: VAR
# Model Number: 72 with model UnivariateMotif in generation 0 of 3
# Template Eval Error: ValueError('kth(=10) out of bounds (5)') in model 72: UnivariateMotif
# Model Number: 73 with model GLM in generation 0 of 3
# Template Eval Error: TypeError("ufunc 'isfinite' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''") in model 73: GLM
# Model Number: 74 with model ETS in generation 0 of 3
# Model Number: 75 with model GLS in generation 0 of 3
# C:\Users\leube\anaconda4\lib\site-packages\statsmodels\genmod\generalized_linear_model.py:298: DomainWarning: The inverse_power link function does not respect the domain of the Gamma family.
#   if exposure is not None:
# Model Number: 76 with model VAR in generation 0 of 3
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 76: VAR
# Model Number: 77 with model UnivariateMotif in generation 0 of 3
# Template Eval Error: ValueError('kth(=10) out of bounds (5)') in model 77: UnivariateMotif
# Model Number: 78 with model SectionalMotif in generation 0 of 3
# Template Eval Error: ValueError('kth(=100) out of bounds (2)') in model 78: SectionalMotif
# Model Number: 79 with model ConstantNaive in generation 0 of 3
# Template Eval Error: Exception('Transformer STLFilter failed on fit') in model 79: ConstantNaive
# Model Number: 80 with model AverageValueNaive in generation 0 of 3
# Model Number: 81 with model SeasonalNaive in generation 0 of 3
# Model Number: 82 with model SectionalMotif in generation 0 of 3
# Template Eval Error: ValueError('kth(=10) out of bounds (5)') in model 82: SectionalMotif
# Model Number: 83 with model SeasonalNaive in generation 0 of 3
# Model Number: 84 with model SectionalMotif in generation 0 of 3
# Template Eval Error: ValueError('kth(=10) out of bounds (5)') in model 84: SectionalMotif
# Model Number: 85 with model ETS in generation 0 of 3
# ETS error ValueError('Cannot compute initial seasonals using heuristic method with less than two full seasonal cycles in the data.')
# ETS failed on ATF_Form_2 with ValueError('Cannot compute initial seasonals using heuristic method with less than two full seasonal cycles in the data.')
# Model Number: 86 with model SeasonalNaive in generation 0 of 3
# Model Number: 87 with model MultivariateMotif in generation 0 of 3
# Model Number: 88 with model SectionalMotif in generation 0 of 3
# Template Eval Error: ValueError('kth(=10) out of bounds (5)') in model 88: SectionalMotif
# Model Number: 89 with model GLS in generation 0 of 3
# Template Eval Error: ValueError('zero-size array to reduction operation maximum which has no identity') in model 89: GLS
# Model Number: 90 with model GLS in generation 0 of 3
# Model Number: 91 with model GLM in generation 0 of 3
# Template Eval Error: ValueError('regression_type=user and no future_regressor passed') in model 91: GLM
# Model Number: 92 with model DatepartRegression in generation 0 of 3
# Template Eval Error: ValueError("regression_type='User' but no future_regressor passed") in model 92: DatepartRegression
# Model Number: 93 with model LastValueNaive in generation 0 of 3
# Model Number: 94 with model ConstantNaive in generation 0 of 3
# Model Number: 95 with model GLM in generation 0 of 3
# Template Eval Error: ValueError('regression_type=user and no future_regressor passed') in model 95: GLM
# Model Number: 96 with model GLS in generation 0 of 3
# Model Number: 97 with model SeasonalNaive in generation 0 of 3
# Model Number: 98 with model LastValueNaive in generation 0 of 3
# Model Number: 99 with model SeasonalNaive in generation 0 of 3
# Model Number: 100 with model SectionalMotif in generation 0 of 3
# Template Eval Error: ValueError('XA and XB must have the same number of columns (i.e. feature dimension.)') in model 100: SectionalMotif
# Model Number: 101 with model ConstantNaive in generation 0 of 3
# Model Number: 102 with model NVAR in generation 0 of 3
# Model Number: 103 with model LastValueNaive in generation 0 of 3
# Model Number: 104 with model ConstantNaive in generation 0 of 3
# Model Number: 105 with model DatepartRegression in generation 0 of 3
# Epoch 1/100
# 1/1 [==============================] - 6s 6s/step - loss: 113512.2344 - val_loss: 238809.7188
# Epoch 2/100
# 1/1 [==============================] - 0s 67ms/step - loss: 113573.1328 - val_loss: 238805.2969
# Epoch 3/100
# 1/1 [==============================] - 0s 86ms/step - loss: 113640.7266 - val_loss: 238800.8594
# Epoch 4/100
# 1/1 [==============================] - 0s 64ms/step - loss: 113516.1484 - val_loss: 238796.4375
# Epoch 5/100
# 1/1 [==============================] - 0s 67ms/step - loss: 113597.1016 - val_loss: 238792.0156
# Epoch 6/100
# 1/1 [==============================] - 0s 92ms/step - loss: 113579.4688 - val_loss: 238787.5938
# Epoch 7/100
# 1/1 [==============================] - 0s 112ms/step - loss: 113557.6250 - val_loss: 238783.1719
# Epoch 8/100
# 1/1 [==============================] - 0s 100ms/step - loss: 113604.4531 - val_loss: 238778.7344
# Epoch 9/100
# 1/1 [==============================] - 0s 123ms/step - loss: 113503.3828 - val_loss: 238774.3125
# Epoch 10/100
# 1/1 [==============================] - 0s 110ms/step - loss: 113485.7578 - val_loss: 238769.8906
# Epoch 11/100
# 1/1 [==============================] - 0s 107ms/step - loss: 113478.4141 - val_loss: 238765.4844
# Epoch 12/100
# 1/1 [==============================] - 0s 103ms/step - loss: 113577.8203 - val_loss: 238761.0938
# Epoch 13/100
# 1/1 [==============================] - 0s 99ms/step - loss: 113479.7656 - val_loss: 238756.6719
# Epoch 14/100
# 1/1 [==============================] - 0s 99ms/step - loss: 113545.1484 - val_loss: 238752.2656
# Epoch 15/100
# 1/1 [==============================] - 0s 100ms/step - loss: 113447.5469 - val_loss: 238747.8594
# Epoch 16/100
# 1/1 [==============================] - 0s 120ms/step - loss: 113447.2266 - val_loss: 238743.4688
# Epoch 17/100
# 1/1 [==============================] - 0s 113ms/step - loss: 113490.3281 - val_loss: 238739.0781
# Epoch 18/100
# 1/1 [==============================] - 0s 99ms/step - loss: 113518.1719 - val_loss: 238734.6875
# Epoch 19/100
# 1/1 [==============================] - 0s 55ms/step - loss: 113626.3828 - val_loss: 238730.2969
# Epoch 20/100
# 1/1 [==============================] - 0s 63ms/step - loss: 113437.8516 - val_loss: 238725.9062
# Epoch 21/100
# 1/1 [==============================] - 0s 107ms/step - loss: 113470.4844 - val_loss: 238721.5156
# Epoch 22/100
# 1/1 [==============================] - 0s 97ms/step - loss: 113529.8594 - val_loss: 238717.1250
# Epoch 23/100
# 1/1 [==============================] - 0s 110ms/step - loss: 113516.6562 - val_loss: 238712.7500
# Epoch 24/100
# 1/1 [==============================] - 0s 109ms/step - loss: 113441.5234 - val_loss: 238708.3594
# Epoch 25/100
# 1/1 [==============================] - 0s 111ms/step - loss: 113456.2266 - val_loss: 238703.9688
# Epoch 26/100
# 1/1 [==============================] - 0s 116ms/step - loss: 113562.1094 - val_loss: 238699.5938
# Epoch 27/100
# 1/1 [==============================] - 0s 99ms/step - loss: 113534.3359 - val_loss: 238695.2031
# Epoch 28/100
# 1/1 [==============================] - 0s 87ms/step - loss: 113510.5703 - val_loss: 238690.8125
# Epoch 29/100
# 1/1 [==============================] - 0s 68ms/step - loss: 113485.5469 - val_loss: 238686.4219
# Epoch 30/100
# 1/1 [==============================] - 0s 93ms/step - loss: 113401.5000 - val_loss: 238682.0312
# Epoch 31/100
# 1/1 [==============================] - 0s 115ms/step - loss: 113461.1250 - val_loss: 238677.6406
# Epoch 32/100
# 1/1 [==============================] - 0s 108ms/step - loss: 113432.7578 - val_loss: 238673.2500
# Epoch 33/100
# 1/1 [==============================] - 0s 76ms/step - loss: 113432.1797 - val_loss: 238668.8594
# Epoch 34/100
# 1/1 [==============================] - 0s 92ms/step - loss: 113429.5156 - val_loss: 238664.4688
# Epoch 35/100
# 1/1 [==============================] - 0s 81ms/step - loss: 113413.8203 - val_loss: 238660.0781
# Epoch 36/100
# 1/1 [==============================] - 0s 102ms/step - loss: 113457.2969 - val_loss: 238655.7031
# Epoch 37/100
# 1/1 [==============================] - 0s 97ms/step - loss: 113456.4844 - val_loss: 238651.3125
# Epoch 38/100
# 1/1 [==============================] - 0s 101ms/step - loss: 113353.2031 - val_loss: 238646.9375
# Epoch 39/100
# 1/1 [==============================] - 0s 109ms/step - loss: 113417.7188 - val_loss: 238642.5469
# Epoch 40/100
# 1/1 [==============================] - 0s 114ms/step - loss: 113467.6484 - val_loss: 238638.1719
# Epoch 41/100
# 1/1 [==============================] - 0s 99ms/step - loss: 113504.8438 - val_loss: 238633.7969
# Epoch 42/100
# 1/1 [==============================] - 0s 116ms/step - loss: 113318.2031 - val_loss: 238629.4219
# Epoch 43/100
# 1/1 [==============================] - 0s 103ms/step - loss: 113343.9297 - val_loss: 238625.0469
# Epoch 44/100
# 1/1 [==============================] - 0s 144ms/step - loss: 113407.2969 - val_loss: 238620.6875
# Epoch 45/100
# 1/1 [==============================] - 0s 103ms/step - loss: 113231.0547 - val_loss: 238616.3125
# Epoch 46/100
# 1/1 [==============================] - 0s 107ms/step - loss: 113308.4531 - val_loss: 238611.9375
# Epoch 47/100
# 1/1 [==============================] - 0s 106ms/step - loss: 113498.9844 - val_loss: 238607.5938
# Epoch 48/100
# 1/1 [==============================] - 0s 71ms/step - loss: 113257.2344 - val_loss: 238603.2188
# Epoch 49/100
# 1/1 [==============================] - 0s 83ms/step - loss: 113394.5000 - val_loss: 238598.8750
# Epoch 50/100
# 1/1 [==============================] - 0s 120ms/step - loss: 113446.3594 - val_loss: 238594.5000
# Epoch 51/100
# 1/1 [==============================] - 0s 83ms/step - loss: 113315.8828 - val_loss: 238590.1250
# Epoch 52/100
# 1/1 [==============================] - 0s 117ms/step - loss: 113345.5156 - val_loss: 238585.7500
# Epoch 53/100
# 1/1 [==============================] - 0s 88ms/step - loss: 113449.5078 - val_loss: 238581.4062
# Epoch 54/100
# 1/1 [==============================] - 0s 94ms/step - loss: 113388.7344 - val_loss: 238577.0312
# Epoch 55/100
# 1/1 [==============================] - 0s 95ms/step - loss: 113330.1328 - val_loss: 238572.6875
# Epoch 56/100
# 1/1 [==============================] - 0s 105ms/step - loss: 113381.0703 - val_loss: 238568.3438
# Epoch 57/100
# 1/1 [==============================] - 0s 101ms/step - loss: 113241.3750 - val_loss: 238563.9688
# Epoch 58/100
# 1/1 [==============================] - 0s 77ms/step - loss: 113352.4297 - val_loss: 238559.6250
# Epoch 59/100
# 1/1 [==============================] - 0s 84ms/step - loss: 113404.2891 - val_loss: 238555.2500
# Epoch 60/100
# 1/1 [==============================] - 0s 103ms/step - loss: 113309.7422 - val_loss: 238550.8750
# Epoch 61/100
# 1/1 [==============================] - 0s 111ms/step - loss: 113365.0156 - val_loss: 238546.5000
# Epoch 62/100
# 1/1 [==============================] - 0s 104ms/step - loss: 113234.2500 - val_loss: 238542.1250
# Epoch 63/100
# 1/1 [==============================] - 0s 115ms/step - loss: 113342.2500 - val_loss: 238537.7500
# Epoch 64/100
# 1/1 [==============================] - 0s 94ms/step - loss: 113397.6797 - val_loss: 238533.3594
# Epoch 65/100
# 1/1 [==============================] - 0s 100ms/step - loss: 113363.6641 - val_loss: 238528.9844
# Epoch 66/100
# 1/1 [==============================] - 0s 117ms/step - loss: 113285.5469 - val_loss: 238524.6250
# Epoch 67/100
# 1/1 [==============================] - 0s 99ms/step - loss: 113379.3672 - val_loss: 238520.2500
# Epoch 68/100
# 1/1 [==============================] - 0s 70ms/step - loss: 113269.3750 - val_loss: 238515.8750
# Epoch 69/100
# 1/1 [==============================] - 0s 96ms/step - loss: 113342.6797 - val_loss: 238511.5000
# Epoch 70/100
# 1/1 [==============================] - 0s 100ms/step - loss: 113303.1250 - val_loss: 238507.1250
# Epoch 71/100
# 1/1 [==============================] - 0s 102ms/step - loss: 113321.4688 - val_loss: 238502.7500
# Epoch 72/100
# 1/1 [==============================] - 0s 93ms/step - loss: 113313.5000 - val_loss: 238498.3750
# Epoch 73/100
# 1/1 [==============================] - 0s 49ms/step - loss: 113330.0469 - val_loss: 238494.0312
# Epoch 74/100
# 1/1 [==============================] - 0s 65ms/step - loss: 113245.7031 - val_loss: 238489.6875
# Epoch 75/100
# 1/1 [==============================] - 0s 81ms/step - loss: 113282.5000 - val_loss: 238485.3750
# Epoch 76/100
# 1/1 [==============================] - 0s 101ms/step - loss: 113178.8672 - val_loss: 238481.0469
# Epoch 77/100
# 1/1 [==============================] - 0s 67ms/step - loss: 113297.3281 - val_loss: 238476.7031
# Epoch 78/100
# 1/1 [==============================] - 0s 104ms/step - loss: 113176.4922 - val_loss: 238472.3750
# Epoch 79/100
# 1/1 [==============================] - 0s 98ms/step - loss: 113296.7031 - val_loss: 238468.0156
# Epoch 80/100
# 1/1 [==============================] - 0s 102ms/step - loss: 113193.5703 - val_loss: 238463.7031
# Epoch 81/100
# 1/1 [==============================] - 0s 98ms/step - loss: 113181.0469 - val_loss: 238459.3750
# Epoch 82/100
# 1/1 [==============================] - 0s 117ms/step - loss: 113243.6641 - val_loss: 238455.0469
# Epoch 83/100
# 1/1 [==============================] - 0s 100ms/step - loss: 113328.2500 - val_loss: 238450.7031
# Epoch 84/100
# 1/1 [==============================] - 0s 115ms/step - loss: 113205.0469 - val_loss: 238446.3750
# Epoch 85/100
# 1/1 [==============================] - 0s 116ms/step - loss: 113157.8594 - val_loss: 238442.0312
# Epoch 86/100
# 1/1 [==============================] - 0s 84ms/step - loss: 113222.6406 - val_loss: 238437.7188
# Epoch 87/100
# 1/1 [==============================] - 0s 83ms/step - loss: 113221.2969 - val_loss: 238433.4062
# Epoch 88/100
# 1/1 [==============================] - 0s 93ms/step - loss: 113207.2031 - val_loss: 238429.0625
# Epoch 89/100
# 1/1 [==============================] - 0s 87ms/step - loss: 113198.2969 - val_loss: 238424.7500
# Epoch 90/100
# 1/1 [==============================] - 0s 89ms/step - loss: 113236.6094 - val_loss: 238420.4375
# Epoch 91/100
# 1/1 [==============================] - 0s 92ms/step - loss: 113291.2656 - val_loss: 238416.1250
# Epoch 92/100
# 1/1 [==============================] - 0s 94ms/step - loss: 113237.9062 - val_loss: 238411.8125
# Epoch 93/100
# 1/1 [==============================] - 0s 102ms/step - loss: 113242.0703 - val_loss: 238407.5000
# Epoch 94/100
# 1/1 [==============================] - 0s 97ms/step - loss: 113155.6172 - val_loss: 238403.1562
# Epoch 95/100
# 1/1 [==============================] - 0s 68ms/step - loss: 113279.3516 - val_loss: 238398.8125
# Epoch 96/100
# 1/1 [==============================] - 0s 83ms/step - loss: 113150.6953 - val_loss: 238394.4688
# Epoch 97/100
# 1/1 [==============================] - 0s 67ms/step - loss: 113207.7344 - val_loss: 238390.1406
# Epoch 98/100
# 1/1 [==============================] - 0s 62ms/step - loss: 113175.5312 - val_loss: 238385.7969
# Epoch 99/100
# 1/1 [==============================] - 0s 85ms/step - loss: 113187.0859 - val_loss: 238381.4531
# Epoch 100/100
# 1/1 [==============================] - 0s 101ms/step - loss: 113099.8828 - val_loss: 238377.0938
# 1/1 [==============================] - 1s 580ms/step
# Template Eval Error: ValueError('Model DatepartRegression returned NaN for one or more series. fail_on_forecast_nan=True') in model 105: DatepartRegression
# Model Number: 106 with model ETS in generation 0 of 3
# ETS error ValueError('Cannot compute initial seasonals using heuristic method with less than two full seasonal cycles in the data.')
# ETS failed on ATF_Form_2 with ValueError('Cannot compute initial seasonals using heuristic method with less than two full seasonal cycles in the data.')
# Model Number: 107 with model GLS in generation 0 of 3
# Model Number: 108 with model ETS in generation 0 of 3
# ETS error ValueError('endog must be strictly positive when usingmultiplicative trend or seasonal components.')
# ETS failed on ATF_Form_2 with ValueError('endog must be strictly positive when usingmultiplicative trend or seasonal components.')
# Model Number: 109 with model GLS in generation 0 of 3
# Model Number: 110 with model LastValueNaive in generation 0 of 3
# Model Number: 111 with model NVAR in generation 0 of 3
# Model Number: 112 with model GLM in generation 0 of 3
# Template Eval Error: TypeError("ufunc 'isfinite' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''") in model 112: GLM
# Model Number: 113 with model VECM in generation 0 of 3
# Template Eval Error: ValueError("regression_type='User' but no future_regressor supplied") in model 113: VECM
# Model Number: 114 with model GLS in generation 0 of 3
# Model Number: 115 with model DatepartRegression in generation 0 of 3
# New Generation: 1 of 3
# Model Number: 116 with model DatepartRegression in generation 1 of 3
# Template Eval Error: Exception('Transformer StandardScaler failed on fit') in model 116: DatepartRegression
# Model Number: 117 with model ETS in generation 1 of 3
# Model Number: 118 with model AverageValueNaive in generation 1 of 3
# Model Number: 119 with model GLS in generation 1 of 3
# C:\Users\leube\anaconda4\lib\site-packages\sklearn\utils\validation.py:1858: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['Timestamp', 'str']. An error will be raised in 1.2.
#   warnings.warn(
# C:\Users\leube\anaconda4\lib\site-packages\sklearn\utils\extmath.py:980: RuntimeWarning: invalid value encountered in true_divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# C:\Users\leube\anaconda4\lib\site-packages\sklearn\utils\extmath.py:985: RuntimeWarning: invalid value encountered in true_divide
#   T = new_sum / new_sample_count
# C:\Users\leube\anaconda4\lib\site-packages\sklearn\utils\extmath.py:1005: RuntimeWarning: invalid value encountered in true_divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
# C:\Users\leube\anaconda4\lib\site-packages\sklearn\utils\validation.py:1858: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['Timestamp', 'str']. An error will be raised in 1.2.
#   warnings.warn(
# Model Number: 120 with model SectionalMotif in generation 1 of 3
# Model Number: 121 with model SeasonalNaive in generation 1 of 3
# Model Number: 122 with model ETS in generation 1 of 3
# Model Number: 123 with model NVAR in generation 1 of 3
# Model Number: 124 with model AverageValueNaive in generation 1 of 3
# Model Number: 125 with model DatepartRegression in generation 1 of 3
# Model Number: 126 with model ETS in generation 1 of 3
# Model Number: 127 with model SeasonalNaive in generation 1 of 3
# Model Number: 128 with model DatepartRegression in generation 1 of 3
# Template Eval Error: ValueError('Input y contains NaN.') in model 128: DatepartRegression
# Model Number: 129 with model ConstantNaive in generation 1 of 3
# Model Number: 130 with model DatepartRegression in generation 1 of 3
# Model Number: 131 with model SeasonalNaive in generation 1 of 3
# Model Number: 132 with model SectionalMotif in generation 1 of 3
# Model Number: 133 with model AverageValueNaive in generation 1 of 3
# Model Number: 134 with model DatepartRegression in generation 1 of 3
# [Parallel(n_jobs=-2)]: Using backend ThreadingBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done  36 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-2)]: Done 186 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-2)]: Done 300 out of 300 | elapsed:    0.2s finished
# [Parallel(n_jobs=7)]: Using backend ThreadingBackend with 7 concurrent workers.
# [Parallel(n_jobs=7)]: Done  36 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=7)]: Done 186 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=7)]: Done 300 out of 300 | elapsed:    0.0s finished
# Model Number: 135 with model DatepartRegression in generation 1 of 3
# [Parallel(n_jobs=-2)]: Using backend ThreadingBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done  36 tasks      | elapsed:    0.0s
# Model Number: 136 with model LastValueNaive in generation 1 of 3
# Model Number: 137 with model ETS in generation 1 of 3
# [Parallel(n_jobs=-2)]: Done 100 out of 100 | elapsed:    0.2s finished
# [Parallel(n_jobs=7)]: Using backend ThreadingBackend with 7 concurrent workers.
# [Parallel(n_jobs=7)]: Done  36 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=7)]: Done 100 out of 100 | elapsed:    0.0s finished
# Model Number: 138 with model ETS in generation 1 of 3
# Template Eval Error: ValueError('Model ETS returned NaN for one or more series. fail_on_forecast_nan=True') in model 138: ETS
# Model Number: 139 with model LastValueNaive in generation 1 of 3
# Model Number: 140 with model SeasonalNaive in generation 1 of 3
# Model Number: 141 with model SeasonalNaive in generation 1 of 3
# Model Number: 142 with model ConstantNaive in generation 1 of 3
# Model Number: 143 with model LastValueNaive in generation 1 of 3
# Model Number: 144 with model ETS in generation 1 of 3
# Model Number: 145 with model AverageValueNaive in generation 1 of 3
# Model Number: 146 with model WindowRegression in generation 1 of 3
# Model Number: 147 with model WindowRegression in generation 1 of 3
# Model Number: 148 with model DatepartRegression in generation 1 of 3
# Template Eval Error: ValueError("regression_type='User' but no future_regressor passed") in model 148: DatepartRegression
# Model Number: 149 with model SectionalMotif in generation 1 of 3
# Model Number: 150 with model LastValueNaive in generation 1 of 3
# Model Number: 151 with model GLS in generation 1 of 3
# Model Number: 152 with model LastValueNaive in generation 1 of 3
# Model Number: 153 with model ConstantNaive in generation 1 of 3
# Model Number: 154 with model GLS in generation 1 of 3
# Model Number: 155 with model DatepartRegression in generation 1 of 3
# [Parallel(n_jobs=-2)]: Using backend ThreadingBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done  36 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-2)]: Done 100 out of 100 | elapsed:    0.1s finished
# [Parallel(n_jobs=7)]: Using backend ThreadingBackend with 7 concurrent workers.
# [Parallel(n_jobs=7)]: Done  36 tasks      | elapsed:    0.0s
# Model Number: 156 with model ETS in generation 1 of 3
# Model Number: 157 with model SeasonalNaive in generation 1 of 3
# [Parallel(n_jobs=7)]: Done 100 out of 100 | elapsed:    0.0s finished
# Model Number: 158 with model ETS in generation 1 of 3
# Model Number: 159 with model DatepartRegression in generation 1 of 3
# [Parallel(n_jobs=-2)]: Using backend ThreadingBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done  36 tasks      | elapsed:    0.0s
# Model Number: 160 with model LastValueNaive in generation 1 of 3
# [Parallel(n_jobs=-2)]: Done 100 out of 100 | elapsed:    0.2s finished
# [Parallel(n_jobs=7)]: Using backend ThreadingBackend with 7 concurrent workers.
# [Parallel(n_jobs=7)]: Done  36 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=7)]: Done 100 out of 100 | elapsed:    0.0s finished
# Model Number: 161 with model DatepartRegression in generation 1 of 3
# Template Eval Error: Exception('Transformer MaxAbsScaler failed on fit') in model 161: DatepartRegression
# Model Number: 162 with model AverageValueNaive in generation 1 of 3
# Model Number: 163 with model DatepartRegression in generation 1 of 3
# Template Eval Error: ValueError('Input y contains NaN.') in model 163: DatepartRegression
# Model Number: 164 with model AverageValueNaive in generation 1 of 3
# Model Number: 165 with model LastValueNaive in generation 1 of 3
# C:\Users\leube\anaconda4\lib\site-packages\sklearn\utils\validation.py:1858: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['Timestamp', 'str']. An error will be raised in 1.2.
#   warnings.warn(
# C:\Users\leube\anaconda4\lib\site-packages\sklearn\preprocessing\_data.py:1186: RuntimeWarning: All-NaN slice encountered
#   max_abs = np.nanmax(np.abs(X), axis=0)
# C:\Users\leube\anaconda4\lib\site-packages\sklearn\utils\validation.py:1858: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['Timestamp', 'str']. An error will be raised in 1.2.
#   warnings.warn(
# Model Number: 166 with model ConstantNaive in generation 1 of 3
# Model Number: 167 with model ETS in generation 1 of 3
# Model Number: 168 with model LastValueNaive in generation 1 of 3
# Model Number: 169 with model GLS in generation 1 of 3
# Model Number: 170 with model ConstantNaive in generation 1 of 3
# Model Number: 171 with model AverageValueNaive in generation 1 of 3
# Model Number: 172 with model LastValueNaive in generation 1 of 3
# Model Number: 173 with model GLS in generation 1 of 3
# Model Number: 174 with model DatepartRegression in generation 1 of 3
# Template Eval Error: Exception('Transformer StandardScaler failed on fit') in model 174: DatepartRegression
# Model Number: 175 with model GLS in generation 1 of 3
# Model Number: 176 with model SeasonalNaive in generation 1 of 3
# Model Number: 177 with model GLS in generation 1 of 3
# C:\Users\leube\anaconda4\lib\site-packages\sklearn\utils\validation.py:1858: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['Timestamp', 'str']. An error will be raised in 1.2.
#   warnings.warn(
# C:\Users\leube\anaconda4\lib\site-packages\sklearn\utils\extmath.py:980: RuntimeWarning: invalid value encountered in true_divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# C:\Users\leube\anaconda4\lib\site-packages\sklearn\utils\extmath.py:985: RuntimeWarning: invalid value encountered in true_divide
#   T = new_sum / new_sample_count
# C:\Users\leube\anaconda4\lib\site-packages\sklearn\utils\extmath.py:1005: RuntimeWarning: invalid value encountered in true_divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
# C:\Users\leube\anaconda4\lib\site-packages\sklearn\utils\validation.py:1858: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['Timestamp', 'str']. An error will be raised in 1.2.
#   warnings.warn(
# Model Number: 178 with model GLS in generation 1 of 3
# Model Number: 179 with model SeasonalNaive in generation 1 of 3
# Model Number: 180 with model ConstantNaive in generation 1 of 3
# Model Number: 181 with model NVAR in generation 1 of 3
# Model Number: 182 with model NVAR in generation 1 of 3
# Model Number: 183 with model LastValueNaive in generation 1 of 3
# Model Number: 184 with model ETS in generation 1 of 3
# Model Number: 185 with model MultivariateMotif in generation 1 of 3
# Model Number: 186 with model MultivariateMotif in generation 1 of 3
# Template Eval Error: ValueError('window shape cannot be larger than input array shape') in model 186: MultivariateMotif
# Model Number: 187 with model LastValueNaive in generation 1 of 3
# Model Number: 188 with model NVAR in generation 1 of 3
# Model Number: 189 with model NVAR in generation 1 of 3
# Model Number: 190 with model GLM in generation 1 of 3
# New Generation: 2 of 3
# Model Number: 191 with model NVAR in generation 2 of 3
# Model Number: 192 with model SeasonalNaive in generation 2 of 3
# Model Number: 193 with model ETS in generation 2 of 3
# Model Number: 194 with model LastValueNaive in generation 2 of 3
# Model Number: 195 with model LastValueNaive in generation 2 of 3
# Model Number: 196 with model SeasonalNaive in generation 2 of 3
# Template Eval Error: Exception('Transformer Detrend failed on fit') in model 196: SeasonalNaive
# Model Number: 197 with model LastValueNaive in generation 2 of 3
# Model Number: 198 with model SectionalMotif in generation 2 of 3
# Template Eval Error: ValueError('XA and XB must have the same number of columns (i.e. feature dimension.)') in model 198: SectionalMotif
# Model Number: 199 with model GLS in generation 2 of 3
# Model Number: 200 with model LastValueNaive in generation 2 of 3
# Model Number: 201 with model SectionalMotif in generation 2 of 3
# Model Number: 202 with model LastValueNaive in generation 2 of 3
# Model Number: 203 with model ETS in generation 2 of 3
# Model Number: 204 with model GLS in generation 2 of 3
# Model Number: 205 with model LastValueNaive in generation 2 of 3
# Model Number: 206 with model ETS in generation 2 of 3
# Model Number: 207 with model NVAR in generation 2 of 3
# Model Number: 208 with model GLS in generation 2 of 3
# Model Number: 209 with model LastValueNaive in generation 2 of 3
# Model Number: 210 with model SeasonalNaive in generation 2 of 3
# Model Number: 211 with model SectionalMotif in generation 2 of 3
# Model Number: 212 with model SectionalMotif in generation 2 of 3
# Model Number: 213 with model SeasonalNaive in generation 2 of 3
# Model Number: 214 with model GLS in generation 2 of 3
# Model Number: 215 with model GLS in generation 2 of 3
# Model Number: 216 with model ETS in generation 2 of 3
# Model Number: 217 with model SeasonalNaive in generation 2 of 3
# Model Number: 218 with model SeasonalNaive in generation 2 of 3
# Model Number: 219 with model MultivariateMotif in generation 2 of 3
# Template Eval Error: ValueError('kth(=10) out of bounds (5)') in model 219: MultivariateMotif
# Model Number: 220 with model AverageValueNaive in generation 2 of 3
# Model Number: 221 with model DatepartRegression in generation 2 of 3
# [Parallel(n_jobs=-2)]: Using backend ThreadingBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done  36 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-2)]: Done 186 tasks      | elapsed:    0.1s
# Model Number: 222 with model DatepartRegression in generation 2 of 3
# [Parallel(n_jobs=-2)]: Done 300 out of 300 | elapsed:    0.2s finished
# [Parallel(n_jobs=7)]: Using backend ThreadingBackend with 7 concurrent workers.
# [Parallel(n_jobs=7)]: Done  36 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=7)]: Done 186 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=7)]: Done 300 out of 300 | elapsed:    0.0s finished
# Model Number: 223 with model SectionalMotif in generation 2 of 3
# Template Eval Error: ValueError('XA and XB must have the same number of columns (i.e. feature dimension.)') in model 223: SectionalMotif
# Model Number: 224 with model SectionalMotif in generation 2 of 3
# Model Number: 225 with model AverageValueNaive in generation 2 of 3
# Model Number: 226 with model MultivariateMotif in generation 2 of 3
# Template Eval Error: ValueError('kth(=10) out of bounds (5)') in model 226: MultivariateMotif
# ...
# [Parallel(n_jobs=7)]: Done 100 out of 100 | elapsed:    0.0s finished
# 30 - DatepartRegression with avg smape 6.07:
# Model Number: 31 of 51 with model DatepartRegression for Validation 2
# [Parallel(n_jobs=-2)]: Using backend ThreadingBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done  36 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-2)]: Done 100 out of 100 | elapsed:    0.1s finished
# [Parallel(n_jobs=7)]: Using backend ThreadingBackend with 7 concurrent workers.
# [Parallel(n_jobs=7)]: Done  36 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=7)]: Done 100 out of 100 | elapsed:    0.0s finished
# 31 - DatepartRegression with avg smape 6.07:
# Model Number: 32 of 51 with model SeasonalNaive for Validation 2
# 32 - SeasonalNaive with avg smape 9.17:
# Model Number: 33 of 51 with model ETS for Validation 2
# 33 - ETS with avg smape 7.51:
# Model Number: 34 of 51 with model SectionalMotif for Validation 2
# Template Eval Error: ValueError('zero-size array to reduction operation fmax which has no identity') in model 34: SectionalMotif
# Model Number: 35 of 51 with model ETS for Validation 2
# ETS error ValueError('Cannot compute initial seasonals using heuristic method with less than two full seasonal cycles in the data.')
# ETS failed on ATF_Form_2 with ValueError('Cannot compute initial seasonals using heuristic method with less than two full seasonal cycles in the data.')
# 35 - ETS with avg smape 41.56:
# Model Number: 36 of 51 with model ETS for Validation 2
# ETS error ValueError('Cannot compute initial seasonals using heuristic method with less than two full seasonal cycles in the data.')
# ETS failed on ATF_Form_2 with ValueError('Cannot compute initial seasonals using heuristic method with less than two full seasonal cycles in the data.')
# 36 - ETS with avg smape 41.56:
# Model Number: 37 of 51 with model NVAR for Validation 2
# 37 - NVAR with avg smape 36.54:
# C:\Users\leube\anaconda4\lib\site-packages\numpy\lib\function_base.py:380: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis)
# C:\Users\leube\anaconda4\lib\site-packages\numpy\core\_methods.py:181: RuntimeWarning: invalid value encountered in true_divide
#   ret = um.true_divide(
# Model Number: 38 of 51 with model NVAR for Validation 2
# 38 - NVAR with avg smape 36.82:
# Model Number: 39 of 51 with model ETS for Validation 2
# 39 - ETS with avg smape 5.08:
# Model Number: 40 of 51 with model WindowRegression for Validation 2
# Template Eval Error: ValueError('Found array with 0 sample(s) (shape=(0, 0)) while a minimum of 1 is required by MLPRegressor.') in model 40: WindowRegression
# Model Number: 41 of 51 with model WindowRegression for Validation 2
# Template Eval Error: ValueError('Found array with 0 sample(s) (shape=(0, 0)) while a minimum of 1 is required by MLPRegressor.') in model 41: WindowRegression
# Model Number: 42 of 51 with model ConstantNaive for Validation 2
# 42 - ConstantNaive with avg smape 22.48:
# Model Number: 43 of 51 with model SeasonalNaive for Validation 2
# 43 - SeasonalNaive with avg smape 11.88:
# Model Number: 44 of 51 with model SeasonalNaive for Validation 2
# 44 - SeasonalNaive with avg smape 9.02:
# Model Number: 45 of 51 with model ConstantNaive for Validation 2
# 45 - ConstantNaive with avg smape 14.03:
# Model Number: 46 of 51 with model ConstantNaive for Validation 2
# 46 - ConstantNaive with avg smape 59.97:
# Model Number: 47 of 51 with model NVAR for Validation 2
# C:\Users\leube\anaconda4\lib\site-packages\autots\tools\probabilistic.py:67: RuntimeWarning: invalid value encountered in true_divide
#   (prior_mu / prior_sigma**2) + ((n * data_mu) / prior_sigma**2)
# C:\Users\leube\anaconda4\lib\site-packages\autots\tools\probabilistic.py:68: RuntimeWarning: divide by zero encountered in true_divide
#   ) / ((1 / prior_sigma**2) + (n / prior_sigma**2))
# 47 - NVAR with avg smape 38.48:
# Model Number: 48 of 51 with model ConstantNaive for Validation 2
# 48 - ConstantNaive with avg smape 21.49:
# Model Number: 49 of 51 with model ConstantNaive for Validation 2
# 49 - ConstantNaive with avg smape 19.98:
# Model Number: 50 of 51 with model WindowRegression for Validation 2
# Template Eval Error: ValueError('Found array with 0 sample(s) (shape=(0, 0)) while a minimum of 1 is required by MLPRegressor.') in model 50: WindowRegression
# Model Number: 51 of 51 with model NVAR for Validation 2
# 51 - NVAR with avg smape 40.66:
# Validation Round: 3
# Model Number: 1 of 51 with model SectionalMotif for Validation 3
# Template Eval Error: ValueError('XA and XB must have the same number of columns (i.e. feature dimension.)') in model 1: SectionalMotif
# Model Number: 2 of 51 with model GLS for Validation 3
# 📈 2 - GLS with avg smape 17.31:
# Model Number: 3 of 51 with model GLS for Validation 3
# 3 - GLS with avg smape 17.31:
# Model Number: 4 of 51 with model AverageValueNaive for Validation 3
# 4 - AverageValueNaive with avg smape 28.67:
# Model Number: 5 of 51 with model LastValueNaive for Validation 3
# 5 - LastValueNaive with avg smape 27.69:
# Model Number: 6 of 51 with model LastValueNaive for Validation 3
# 6 - LastValueNaive with avg smape 27.69:
# Model Number: 7 of 51 with model WindowRegression for Validation 3
# Template Eval Error: ValueError('Found array with 0 sample(s) (shape=(0, 0)) while a minimum of 1 is required by MLPRegressor.') in model 7: WindowRegression
# Model Number: 8 of 51 with model LastValueNaive for Validation 3
# 8 - LastValueNaive with avg smape 27.69:
# Model Number: 9 of 51 with model LastValueNaive for Validation 3
# 9 - LastValueNaive with avg smape 27.69:
# Model Number: 10 of 51 with model LastValueNaive for Validation 3
# 10 - LastValueNaive with avg smape 27.69:
# Model Number: 11 of 51 with model SectionalMotif for Validation 3
# Template Eval Error: ValueError('XA and XB must have the same number of columns (i.e. feature dimension.)') in model 11: SectionalMotif
# Model Number: 12 of 51 with model AverageValueNaive for Validation 3
# 12 - AverageValueNaive with avg smape 35.08:
# Model Number: 13 of 51 with model AverageValueNaive for Validation 3
# 13 - AverageValueNaive with avg smape 48.27:
# Model Number: 14 of 51 with model SeasonalNaive for Validation 3
# 14 - SeasonalNaive with avg smape 48.27:
# Model Number: 15 of 51 with model SectionalMotif for Validation 3
# Template Eval Error: ValueError('XA and XB must have the same number of columns (i.e. feature dimension.)') in model 15: SectionalMotif
# Model Number: 16 of 51 with model DatepartRegression for Validation 3
# C:\Users\leube\anaconda4\lib\site-packages\autots\tools\probabilistic.py:67: RuntimeWarning: invalid value encountered in true_divide
#   (prior_mu / prior_sigma**2) + ((n * data_mu) / prior_sigma**2)
# C:\Users\leube\anaconda4\lib\site-packages\autots\tools\probabilistic.py:68: RuntimeWarning: divide by zero encountered in true_divide
#   ) / ((1 / prior_sigma**2) + (n / prior_sigma**2))
# [Parallel(n_jobs=-2)]: Using backend ThreadingBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done  36 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-2)]: Done 186 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-2)]: Done 300 out of 300 | elapsed:    0.3s finished
# [Parallel(n_jobs=7)]: Using backend ThreadingBackend with 7 concurrent workers.
# [Parallel(n_jobs=7)]: Done  36 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=7)]: Done 186 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=7)]: Done 300 out of 300 | elapsed:    0.0s finished
# 📈 16 - DatepartRegression with avg smape 14.7:
# Model Number: 17 of 51 with model AverageValueNaive for Validation 3
# 17 - AverageValueNaive with avg smape 34.34:
# Model Number: 18 of 51 with model SectionalMotif for Validation 3
# Template Eval Error: ValueError('XA and XB must have the same number of columns (i.e. feature dimension.)') in model 18: SectionalMotif
# Model Number: 19 of 51 with model MultivariateMotif for Validation 3
# Template Eval Error: ValueError('window shape cannot be larger than input array shape') in model 19: MultivariateMotif
# Model Number: 20 of 51 with model MultivariateMotif for Validation 3
# Template Eval Error: ValueError('window shape cannot be larger than input array shape') in model 20: MultivariateMotif
# Model Number: 21 of 51 with model AverageValueNaive for Validation 3
# 21 - AverageValueNaive with avg smape 31.61:
# Model Number: 22 of 51 with model DatepartRegression for Validation 3
# 22 - DatepartRegression with avg smape 18.02:
# Model Number: 23 of 51 with model DatepartRegression for Validation 3
# 23 - DatepartRegression with avg smape 18.02:
# Model Number: 24 of 51 with model MultivariateMotif for Validation 3
# Template Eval Error: ValueError('window shape cannot be larger than input array shape') in model 24: MultivariateMotif
# Model Number: 25 of 51 with model ETS for Validation 3
# C:\Users\leube\anaconda4\lib\site-packages\autots\tools\probabilistic.py:67: RuntimeWarning: invalid value encountered in true_divide
#   (prior_mu / prior_sigma**2) + ((n * data_mu) / prior_sigma**2)
# C:\Users\leube\anaconda4\lib\site-packages\autots\tools\probabilistic.py:68: RuntimeWarning: divide by zero encountered in true_divide
#   ) / ((1 / prior_sigma**2) + (n / prior_sigma**2))
# C:\Users\leube\anaconda4\lib\site-packages\autots\tools\probabilistic.py:67: RuntimeWarning: invalid value encountered in true_divide
#   (prior_mu / prior_sigma**2) + ((n * data_mu) / prior_sigma**2)
# C:\Users\leube\anaconda4\lib\site-packages\autots\tools\probabilistic.py:68: RuntimeWarning: divide by zero encountered in true_divide
#   ) / ((1 / prior_sigma**2) + (n / prior_sigma**2))
# 25 - ETS with avg smape 28.63:
# Model Number: 26 of 51 with model GLS for Validation 3
# 26 - GLS with avg smape 25.12:
# Model Number: 27 of 51 with model GLS for Validation 3
# 27 - GLS with avg smape 25.12:
# Model Number: 28 of 51 with model SeasonalNaive for Validation 3
# 28 - SeasonalNaive with avg smape 30.82:
# Model Number: 29 of 51 with model GLS for Validation 3
# 29 - GLS with avg smape 24.77:
# Model Number: 30 of 51 with model DatepartRegression for Validation 3
# C:\Users\leube\anaconda4\lib\site-packages\autots\tools\probabilistic.py:67: RuntimeWarning: invalid value encountered in true_divide
#   (prior_mu / prior_sigma**2) + ((n * data_mu) / prior_sigma**2)
# C:\Users\leube\anaconda4\lib\site-packages\autots\tools\probabilistic.py:68: RuntimeWarning: divide by zero encountered in true_divide
#   ) / ((1 / prior_sigma**2) + (n / prior_sigma**2))
# [Parallel(n_jobs=-2)]: Using backend ThreadingBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done  36 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-2)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=7)]: Using backend ThreadingBackend with 7 concurrent workers.
# [Parallel(n_jobs=7)]: Done  36 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=7)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=-2)]: Using backend ThreadingBackend with 7 concurrent workers.
# 30 - DatepartRegression with avg smape 48.27:
# Model Number: 31 of 51 with model DatepartRegression for Validation 3
# [Parallel(n_jobs=-2)]: Done  36 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-2)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=7)]: Using backend ThreadingBackend with 7 concurrent workers.
# [Parallel(n_jobs=7)]: Done  36 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=7)]: Done 100 out of 100 | elapsed:    0.0s finished
# C:\Users\leube\anaconda4\lib\site-packages\autots\tools\probabilistic.py:67: RuntimeWarning: invalid value encountered in true_divide
#   (prior_mu / prior_sigma**2) + ((n * data_mu) / prior_sigma**2)
# C:\Users\leube\anaconda4\lib\site-packages\autots\tools\probabilistic.py:68: RuntimeWarning: divide by zero encountered in true_divide
#   ) / ((1 / prior_sigma**2) + (n / prior_sigma**2))
# 31 - DatepartRegression with avg smape 48.27:
# Model Number: 32 of 51 with model SeasonalNaive for Validation 3
# 32 - SeasonalNaive with avg smape 30.84:
# Model Number: 33 of 51 with model ETS for Validation 3
# 📈 33 - ETS with avg smape 11.63:
# Model Number: 34 of 51 with model SectionalMotif for Validation 3
# Template Eval Error: ValueError('XA and XB must have the same number of columns (i.e. feature dimension.)') in model 34: SectionalMotif
# Model Number: 35 of 51 with model ETS for Validation 3
# ETS error ValueError('Cannot compute initial seasonals using heuristic method with less than two full seasonal cycles in the data.')
# ETS failed on ATF_Form_2 with ValueError('Cannot compute initial seasonals using heuristic method with less than two full seasonal cycles in the data.')
# 35 - ETS with avg smape 28.45:
# Model Number: 36 of 51 with model ETS for Validation 3
# ETS error ValueError('Cannot compute initial seasonals using heuristic method with less than two full seasonal cycles in the data.')
# ETS failed on ATF_Form_2 with ValueError('Cannot compute initial seasonals using heuristic method with less than two full seasonal cycles in the data.')
# 36 - ETS with avg smape 28.45:
# Model Number: 37 of 51 with model NVAR for Validation 3
# Template Eval Error: IndexError('index -5 is out of bounds for axis 1 with size 4') in model 37: NVAR
# Model Number: 38 of 51 with model NVAR for Validation 3
# Template Eval Error: IndexError('index -5 is out of bounds for axis 1 with size 4') in model 38: NVAR
# Model Number: 39 of 51 with model ETS for Validation 3
# 39 - ETS with avg smape 14.92:
# Model Number: 40 of 51 with model WindowRegression for Validation 3
# Template Eval Error: ValueError('Found array with 0 sample(s) (shape=(0, 0)) while a minimum of 1 is required by MLPRegressor.') in model 40: WindowRegression
# Model Number: 41 of 51 with model WindowRegression for Validation 3
# Template Eval Error: ValueError('Found array with 0 sample(s) (shape=(0, 0)) while a minimum of 1 is required by MLPRegressor.') in model 41: WindowRegression
# Model Number: 42 of 51 with model ConstantNaive for Validation 3
# 42 - ConstantNaive with avg smape 22.81:
# Model Number: 43 of 51 with model SeasonalNaive for Validation 3
# 43 - SeasonalNaive with avg smape 48.27:
# Model Number: 44 of 51 with model SeasonalNaive for Validation 3
# 44 - SeasonalNaive with avg smape 19.48:
# Model Number: 45 of 51 with model ConstantNaive for Validation 3
# C:\Users\leube\anaconda4\lib\site-packages\sklearn\decomposition\_pca.py:527: RuntimeWarning: invalid value encountered in true_divide
#   explained_variance_ratio_ = explained_variance_ / total_var
# C:\Users\leube\anaconda4\lib\site-packages\autots\tools\probabilistic.py:67: RuntimeWarning: invalid value encountered in true_divide
#   (prior_mu / prior_sigma**2) + ((n * data_mu) / prior_sigma**2)
# C:\Users\leube\anaconda4\lib\site-packages\autots\tools\probabilistic.py:68: RuntimeWarning: divide by zero encountered in true_divide
#   ) / ((1 / prior_sigma**2) + (n / prior_sigma**2))
# C:\Users\leube\anaconda4\lib\site-packages\autots\tools\probabilistic.py:67: RuntimeWarning: invalid value encountered in true_divide
#   (prior_mu / prior_sigma**2) + ((n * data_mu) / prior_sigma**2)
# C:\Users\leube\anaconda4\lib\site-packages\autots\tools\probabilistic.py:68: RuntimeWarning: divide by zero encountered in true_divide
#   ) / ((1 / prior_sigma**2) + (n / prior_sigma**2))
# 45 - ConstantNaive with avg smape 26.95:
# Model Number: 46 of 51 with model ConstantNaive for Validation 3
# 46 - ConstantNaive with avg smape 36.31:
# Model Number: 47 of 51 with model NVAR for Validation 3
# Template Eval Error: IndexError('index -5 is out of bounds for axis 1 with size 4') in model 47: NVAR
# Model Number: 48 of 51 with model ConstantNaive for Validation 3
# 48 - ConstantNaive with avg smape 49.46:
# Model Number: 49 of 51 with model ConstantNaive for Validation 3
# 49 - ConstantNaive with avg smape 49.46:
# Model Number: 50 of 51 with model WindowRegression for Validation 3
# Template Eval Error: ValueError('Found array with 0 sample(s) (shape=(0, 0)) while a minimum of 1 is required by MLPRegressor.') in model 50: WindowRegression
# Model Number: 51 of 51 with model NVAR for Validation 3
# Template Eval Error: IndexError('index -5 is out of bounds for axis 1 with size 4') in model 51: NVAR

# %%
dataweapall
# Out:
#     Calendar_Year  ATF_Form_2
# 0            1990       66084
# 1            1991       80619
# 2            1992      107313
# 3            1993       70342
# 4            1994       97665
# 5            1995       95061
# 6            1996      103511
# 7            1997      110423
# 8            1998      141101
# 9            1999      137373
# 10           2000      141763
# 11           2001      145112
# 12           2002      162321
# 13           2003      156620
# 14           2004       83483
# 15           2005       65865
# 16           2006      188134
# 17           2007      296267
# 18           2008      424743
# 19           2009      371920
# 20           2010      296375
# 21           2011      530953
# 22           2012      484928
# 23           2013      477567
# 24           2014      591388

# %%
prediction = model.predict()
prediction
prediction.forecast.set_index(pd.Index(list(np.arange(24,29))),inplace=True)
forecastdfnew2 = prediction.upper_forecast
prediction.upper_forecast.set_index(pd.Index(list(np.arange(24,29))),inplace=True)
forecastdfnew = prediction.forecast
prediction.lower_forecast.set_index(pd.Index(list(np.arange(24,29))),inplace=True)
forecastdfnew3 = prediction.upper_forecast

plt.plot(dataweapall['ATF_Form_2'], color = "black")
plt.plot(forecastdfnew2['ATF_Form_2'], color='red')
plt.plot(forecastdfnew['ATF_Form_2'], color='blue')
plt.plot(forecastdfnew3['ATF_Form_2'], color='green')
plt.title("Train/Test split guns registered")
plt.ylabel("guns")
plt.xlabel('Year')
sns.set()
plt.show()

# %%
# forecast 3 seems to follow tredn best

# make a new dataframe finished and update the file below to folder, then go and run the model again with updated data frame

# check results, but everything should be the same

# %%
finfore = pd.DataFrame({'Calendar_Year':list(np.arange(2015,2019)), 'ATF_Form_2':list(forecastdfnew3['ATF_Form_2'].values)[1:]})

# %%
finweap = pd.concat([dataweapall, finfore],axis=0,ignore_index=True)

# %%
finweap = finweap[finweap['Calendar_Year']>=2002]

# %%
finweap.to_csv(r'C:\Users\leube\Ironhack\Ironprojects\Module_3\final_project\the-dark-side-of-social-media-\clean_data\weapons_US_cleaned.csv')
